# %%
from __future__ import print_function
import os

import pandas as pd
from PIL import Image
import numpy as np

import chainer
from chainer.dataset import convert
import chainer.links as L
import chainer.functions as F
from chainer import serializers

from chainer.datasets import get_cifar10
from chainer.datasets import get_cifar100

import utils
# Out:
# Using TensorFlow backend.
# /home/fytroo/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# ### ハイパーパラメータ

# %%
from easydict import EasyDict
args = EasyDict({
    'bs': 64, 
    'epoch' : 100,
    'lr' : 0.05,
    'gpu': 0,
    'out': 'result',
    'resume': '',
    'n_in': 32, 
})
try:
    __file__.endswith('py')
    import argparse
    parser = argparse.ArgumentParser(description='Chainer example: MNIST')
    parser.add_argument('--batchsize', '-b', dest='bs', type=int, default=args.bs,
                        help='Number of images in each mini-batch')
    parser.add_argument('--epoch', '-e', type=int, default=args.epoch,
                        help='Number of sweeps over the dataset to train')
    parser.add_argument('--learningrate', '-l', dest='lr', type=float, default=args.lr,
                        help='Number of sweeps over the dataset to train')
    parser.add_argument('--frequency', '-f', type=int, default=-1,
                        help='Frequency of taking a snapshot')
    parser.add_argument('--gpu', '-g', type=int, default=args.gpu,
                        help='GPU ID (negative value indicates CPU)')
    parser.add_argument('--out', '-o', default=args.out,
                        help='Directory to output the result')
    parser.add_argument('--resume', '-r', default=args.resume,
                        help='Resume the training from snapshot')
    parser.add_argument('--unit', '-u', dest='n_in', type=int, default=args.n_in,
                        help='Number of units')
    parser.add_argument('--noplot', dest='plot', action='store_false',
                        help='Disable PlotReport extension')
    args = parser.parse_args()
except:
    print('no argsparse')
    pass
# Out:
# no argsparse

# %% [markdown]
# ### データセット読み込み

# %%
dataset_dir = 'flower_images'
df  = pd.DataFrame.from_csv(os.path.join(dataset_dir,'flower_labels.csv'))

df['name'] = df.index
df['path'] = dataset_dir + '/' + df['name']

n_label = df.label.drop_duplicates().count()
n_label
df
# Out:
# /home/fytroo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#           label      name                    path
# file
# 0001.png      0  0001.png  flower_images/0001.png
# 0002.png      0  0002.png  flower_images/0002.png
# 0003.png      2  0003.png  flower_images/0003.png
# 0004.png      0  0004.png  flower_images/0004.png
# 0005.png      0  0005.png  flower_images/0005.png
# 0006.png      1  0006.png  flower_images/0006.png
# 0007.png      6  0007.png  flower_images/0007.png
# 0008.png      0  0008.png  flower_images/0008.png
# 0009.png      0  0009.png  flower_images/0009.png
# 0010.png      0  0010.png  flower_images/0010.png
# 0011.png      0  0011.png  flower_images/0011.png
# 0012.png      0  0012.png  flower_images/0012.png
# 0013.png      0  0013.png  flower_images/0013.png
# 0014.png      7  0014.png  flower_images/0014.png
# 0015.png      7  0015.png  flower_images/0015.png
# 0016.png      1  0016.png  flower_images/0016.png
# 0017.png      0  0017.png  flower_images/0017.png
# 0018.png      0  0018.png  flower_images/0018.png
# 0019.png      6  0019.png  flower_images/0019.png
# 0020.png      0  0020.png  flower_images/0020.png
# 0021.png      2  0021.png  flower_images/0021.png
# 0022.png      4  0022.png  flower_images/0022.png
# 0023.png      7  0023.png  flower_images/0023.png
# 0024.png      4  0024.png  flower_images/0024.png
# 0025.png      5  0025.png  flower_images/0025.png
# 0026.png      6  0026.png  flower_images/0026.png
# 0027.png      2  0027.png  flower_images/0027.png
# 0028.png      5  0028.png  flower_images/0028.png
# 0029.png      6  0029.png  flower_images/0029.png
# 0030.png      6  0030.png  flower_images/0030.png
# ...         ...       ...                     ...
# 0181.png      0  0181.png  flower_images/0181.png
# 0182.png      5  0182.png  flower_images/0182.png
# 0183.png      8  0183.png  flower_images/0183.png
# 0184.png      6  0184.png  flower_images/0184.png
# 0185.png      3  0185.png  flower_images/0185.png
# 0186.png      9  0186.png  flower_images/0186.png
# 0187.png      6  0187.png  flower_images/0187.png
# 0188.png      1  0188.png  flower_images/0188.png
# 0189.png      3  0189.png  flower_images/0189.png
# 0190.png      7  0190.png  flower_images/0190.png
# 0191.png      4  0191.png  flower_images/0191.png
# 0192.png      7  0192.png  flower_images/0192.png
# 0193.png      1  0193.png  flower_images/0193.png
# 0194.png      9  0194.png  flower_images/0194.png
# 0195.png      8  0195.png  flower_images/0195.png
# 0196.png      3  0196.png  flower_images/0196.png
# 0197.png      6  0197.png  flower_images/0197.png
# 0198.png      5  0198.png  flower_images/0198.png
# 0199.png      6  0199.png  flower_images/0199.png
# 0200.png      4  0200.png  flower_images/0200.png
# 0201.png      1  0201.png  flower_images/0201.png
# 0202.png      3  0202.png  flower_images/0202.png
# 0203.png      8  0203.png  flower_images/0203.png
# 0204.png      5  0204.png  flower_images/0204.png
# 0205.png      4  0205.png  flower_images/0205.png
# 0206.png      6  0206.png  flower_images/0206.png
# 0207.png      0  0207.png  flower_images/0207.png
# 0208.png      4  0208.png  flower_images/0208.png
# 0209.png      6  0209.png  flower_images/0209.png
# 0210.png      1  0210.png  flower_images/0210.png
#
# [210 rows x 3 columns]

# %%
def load_fromdf(dataframe, resize=(96,96)):
    if type(resize) is int:
        resize = (resize, resize)
    
    df = dataframe
    x_data = []
    y_data = []
    for idx, row in df.iterrows():
        y = row['label']
        f = row['path']

        img = Image.open(f).resize(resize, Image.LANCZOS)
        img = img.convert('RGB')
        x = np.array(img)
        x_data.append(x)
        y_data.append(y)
    x_data = np.array(x_data)
    y_data = np.array(y_data)

    return x_data, y_data

# %%
df_train, df_test = utils.train_test_split_df(df, test_size=0.1)
x_train, y_train = load_fromdf(df_train, resize=args.n_in)
x_test, y_test = load_fromdf(df_test, resize=args.n_in)

x_train.shape
# Out:
# (200, 32, 32, 3)

# %% [markdown]
# ### モデルを定義

# %%
class Block(chainer.Chain):
    def __init__(self, n_in=32, n_out=32, width=16, depth=1):
        super(Block, self).__init__()
        self.depth = depth
        ch = width
        with self.init_scope():
            self.bn1 = L.BatchNormalization(n_in)
            self.conv1 = L.Convolution2D(None, ch, 1, 1, 0)
            self.bn2 = L.BatchNormalization(ch)
            self.conv2 = L.Convolution2D(None, ch, 1, 1, 0)
            self.bn3 = L.BatchNormalization(ch)
            self.conv3 = L.Convolution2D(None, n_out, 1, 1, 0)
    
    def __call__(self, x):
        h = x
        h = self.bn1(h)
        h = F.relu(h)
        h = self.conv1(h)
        h = self.bn2(h)
        h = F.relu(h)
        h = self.conv2(h)
        h = self.bn3(h)
        h = F.relu(h)
        h = self.conv3(h)
        x = h
        return x

# %%
class LeNet(chainer.Chain):
    def __init__(self, n_in=32, n_out=10):
        super(LeNet, self).__init__()
        with self.init_scope():
            self.conv1 = L.Convolution2D(None, 16, 3)
            self.block1 = Block(16, 32, width=32, depth=2)
            self.block2 = Block(32, 64, width=32, depth=2)
            self.fc = L.Linear(None, n_out)
    
    def __call__(self, x):
        x = self.conv1(x)
        #x = F.dropout(x, 0.25)
        x = self.block1(x)
        x = F.max_pooling_2d(x, ksize=2, stride=2)
        #x = F.dropout(x, 0.25)
        x = self.block2(x)
        #x = F.dropout(x, 0.25)
        x = F.average_pooling_2d(x, ksize=2, stride=2)
        x = self.fc(x)
        return x

# %%
model = L.Classifier(LeNet(args.n_in, n_label),
                    lossfun=F.softmax_cross_entropy,
                    accfun=F.accuracy)
xp = np
if args.gpu >= 0:
    import cupy as cp
    xp = cp
    chainer.cuda.get_device_from_id(args.gpu).use()
    model.to_gpu()  # Copy the model to the GPU
optimizer = chainer.optimizers.MomentumSGD(args.lr)
optimizer.setup(model)

# %% [markdown]
# ### data augmentation

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape

import Augmentor
p = Augmentor.Pipeline()
p.flip_left_right(probability=0.5)
p.flip_top_bottom(probability=0.5)
g = p.keras_generator_from_array(x_train, y_train, batch_size=args.bs)
g = ((
    xp.array(np.swapaxes((x/255.), 1, 3)).astype(np.float32),
    xp.array(y.astype(np.int8))
    ) for (x,y) in g)

# %% [markdown]
# chainer.trainingを使わず，訓練ループをかく
# chainer.trainingでは，自前のデータのイテレータを使うことができないため．
# Augmentorを使いたい

# %% [markdown]
# ### 訓練と検証

# %%
def train(step=None):
    total_loss = 0
    total_acc = 0
    n_data = 0
    n_train = len(y_train)
    for _ in range(n_train//args.bs):
        xs, ts = next(g) 
        x = chainer.Variable(xs)
        t = chainer.Variable(ts)
        optimizer.update(model, x, t)
        with chainer.using_config('train', True):
            loss = model(x,t)
        n_data += len(t.data)
        total_loss += float(loss.data) * len(t.data)
        total_acc += float(model.accuracy.data) * len(t.data)

    loss = total_loss / n_data
    acc = total_acc / n_data
    print('loss: {:.4f}\t acc: {:.4f}'.format(loss, acc))

def test(step=None):
    xs = xp.array(np.swapaxes((x_test), 1, 3)).astype(np.float32)
    ts = xp.array(y_test).astype(np.int8)
    x = chainer.Variable(xs)
    t = chainer.Variable(ts)
    loss = model(x,t)

    n_data = len(t.data)
    total_loss = float(loss.data) * len(t.data)
    total_acc = float(model.accuracy.data) * len(t.data)
    loss = total_loss / n_data
    acc = total_acc / n_data
    print('val_loss: {:.4f}\t val_acc: {:.4f}'.format(loss, acc))

# %%
if __name__ == '__main__':
    for step in range(args.epoch):
        print('step:{}'.format(step))
        train(step)
        test(step)
# Out:
# step:0
# loss: 2.1130	 acc: 0.3698
# val_loss: 2.2154	 val_acc: 0.3000
# step:1
# loss: 1.3480	 acc: 0.5990
# val_loss: 1.3579	 val_acc: 0.5000
# step:2
# loss: 1.0890	 acc: 0.6302
# val_loss: 0.9374	 val_acc: 0.6000
# step:3
# loss: 0.8334	 acc: 0.7396
# val_loss: 0.9198	 val_acc: 0.7000
# step:4
# loss: 0.5717	 acc: 0.7552
# val_loss: 0.6345	 val_acc: 0.7000
# step:5
# loss: 0.7296	 acc: 0.7500
# val_loss: 0.3949	 val_acc: 0.9000
# step:6
# loss: 0.6401	 acc: 0.8385
# val_loss: 0.5931	 val_acc: 0.8000
# step:7
# loss: 0.5945	 acc: 0.8021
# val_loss: 0.4796	 val_acc: 0.8000
# step:8
# loss: 0.6036	 acc: 0.7917
# val_loss: 0.5217	 val_acc: 0.7000
# step:9
# loss: 0.4846	 acc: 0.8542
# val_loss: 0.6368	 val_acc: 0.7000
# step:10
# loss: 0.4176	 acc: 0.8542
# val_loss: 0.3506	 val_acc: 0.9000
# step:11
# loss: 0.3141	 acc: 0.9115
# val_loss: 0.5485	 val_acc: 0.7000
# step:12
# loss: 0.2952	 acc: 0.9062
# val_loss: 0.3703	 val_acc: 0.9000
# step:13
# loss: 0.2641	 acc: 0.8750
# val_loss: 0.6171	 val_acc: 0.7000
# step:14
# loss: 0.2637	 acc: 0.8958
# val_loss: 0.9720	 val_acc: 0.6000
# step:15
# loss: 0.2398	 acc: 0.9167
# val_loss: 0.3786	 val_acc: 0.8000
# step:16
# loss: 0.1945	 acc: 0.9479
# val_loss: 0.9869	 val_acc: 0.7000
# step:17
# loss: 0.2081	 acc: 0.9271
# val_loss: 1.0529	 val_acc: 0.7000
# step:18
# loss: 0.1484	 acc: 0.9531
# val_loss: 0.9835	 val_acc: 0.6000
# step:19
# loss: 0.1511	 acc: 0.9531
# val_loss: 0.2056	 val_acc: 1.0000
# step:20
# loss: 0.1807	 acc: 0.9323
# val_loss: 0.1581	 val_acc: 1.0000
# step:21
# loss: 0.1714	 acc: 0.9427
# val_loss: 0.8249	 val_acc: 0.7000
# step:22
# loss: 0.1434	 acc: 0.9479
# val_loss: 0.3099	 val_acc: 0.9000
# step:23
# loss: 0.1815	 acc: 0.9479
# val_loss: 0.5142	 val_acc: 0.7000
# step:24
# loss: 0.1194	 acc: 0.9635
# val_loss: 0.5826	 val_acc: 0.8000
# step:25
# loss: 0.1228	 acc: 0.9531
# val_loss: 0.6413	 val_acc: 0.7000
# step:26
# loss: 0.1036	 acc: 0.9635
# val_loss: 0.7054	 val_acc: 0.7000
# step:27
# loss: 0.1399	 acc: 0.9531
# val_loss: 0.9377	 val_acc: 0.7000
# step:28
# loss: 0.0630	 acc: 0.9844
# val_loss: 1.0742	 val_acc: 0.7000
# step:29
# loss: 0.0764	 acc: 0.9792
# val_loss: 0.6257	 val_acc: 0.7000
# step:30
# loss: 0.0806	 acc: 0.9844
# val_loss: 0.7682	 val_acc: 0.6000
# step:31
# loss: 0.0592	 acc: 0.9948
# val_loss: 0.5676	 val_acc: 0.7000
# step:32
# loss: 0.0781	 acc: 0.9792
# val_loss: 0.7867	 val_acc: 0.8000
# step:33
# loss: 0.0292	 acc: 1.0000
# val_loss: 1.2398	 val_acc: 0.6000
# step:34
# loss: 0.0453	 acc: 0.9896
# val_loss: 1.4724	 val_acc: 0.6000
# step:35
# loss: 0.0347	 acc: 0.9948
# val_loss: 1.5464	 val_acc: 0.5000
# step:36
# loss: 0.0383	 acc: 0.9948
# val_loss: 1.6979	 val_acc: 0.6000
# step:37
# loss: 0.0178	 acc: 1.0000
# val_loss: 1.3292	 val_acc: 0.6000
# step:38
# loss: 0.0310	 acc: 0.9948
# val_loss: 0.7280	 val_acc: 0.8000
# step:39
# loss: 0.0250	 acc: 0.9896
# val_loss: 0.6079	 val_acc: 0.8000
# step:40
# loss: 0.0171	 acc: 1.0000
# val_loss: 1.1525	 val_acc: 0.7000
# step:41
# loss: 0.0311	 acc: 0.9896
# val_loss: 1.8781	 val_acc: 0.6000
# step:42
# loss: 0.0152	 acc: 1.0000
# val_loss: 2.6161	 val_acc: 0.6000
# step:43
# loss: 0.0307	 acc: 0.9896
# val_loss: 2.1621	 val_acc: 0.6000
# step:44
# loss: 0.0244	 acc: 0.9948
# val_loss: 1.4279	 val_acc: 0.6000
# step:45
# loss: 0.0131	 acc: 1.0000
# val_loss: 2.0925	 val_acc: 0.7000
# step:46
# loss: 0.0210	 acc: 1.0000
# val_loss: 1.9334	 val_acc: 0.7000
# step:47
# loss: 0.0129	 acc: 1.0000
# val_loss: 1.4328	 val_acc: 0.7000
# step:48
# loss: 0.0067	 acc: 1.0000
# val_loss: 1.1102	 val_acc: 0.6000
# step:49
# loss: 0.0163	 acc: 1.0000
# val_loss: 1.0103	 val_acc: 0.6000
# step:50
# loss: 0.0113	 acc: 1.0000
# val_loss: 0.9535	 val_acc: 0.7000
# step:51
# loss: 0.0151	 acc: 1.0000
# val_loss: 0.9288	 val_acc: 0.7000
# step:52
# loss: 0.0186	 acc: 0.9948
# val_loss: 0.9857	 val_acc: 0.7000
# step:53
# loss: 0.0175	 acc: 1.0000
# val_loss: 1.4336	 val_acc: 0.7000
# step:54
# loss: 0.0078	 acc: 1.0000
# val_loss: 1.5931	 val_acc: 0.7000
# step:55
# loss: 0.0081	 acc: 1.0000
# val_loss: 1.6080	 val_acc: 0.7000
# step:56
# loss: 0.0104	 acc: 1.0000
# val_loss: 1.0657	 val_acc: 0.8000
# step:57
# loss: 0.0108	 acc: 1.0000
# val_loss: 0.6983	 val_acc: 0.9000
# step:58
# loss: 0.0154	 acc: 0.9948
# val_loss: 0.7718	 val_acc: 0.8000
# step:59
# loss: 0.0057	 acc: 1.0000
# val_loss: 0.8866	 val_acc: 0.8000
# step:60
# loss: 0.0053	 acc: 1.0000
# val_loss: 1.1724	 val_acc: 0.7000
# step:61
# loss: 0.0071	 acc: 1.0000
# val_loss: 1.2963	 val_acc: 0.7000
# step:62
# loss: 0.0028	 acc: 1.0000
# val_loss: 1.3493	 val_acc: 0.7000
# step:63
# loss: 0.0025	 acc: 1.0000
# val_loss: 1.3953	 val_acc: 0.7000
# step:64
# loss: 0.0036	 acc: 1.0000
# val_loss: 1.3547	 val_acc: 0.7000
# step:65
# loss: 0.0039	 acc: 1.0000
# val_loss: 1.2354	 val_acc: 0.7000
# step:66
# loss: 0.0039	 acc: 1.0000
# val_loss: 1.1574	 val_acc: 0.7000
# step:67
# loss: 0.0016	 acc: 1.0000
# val_loss: 1.0882	 val_acc: 0.7000
# step:68
# loss: 0.0031	 acc: 1.0000
# val_loss: 1.0307	 val_acc: 0.7000
# step:69
# loss: 0.0027	 acc: 1.0000
# val_loss: 1.0059	 val_acc: 0.7000
# step:70
# loss: 0.0025	 acc: 1.0000
# val_loss: 0.9490	 val_acc: 0.7000
# step:71
# loss: 0.0029	 acc: 1.0000
# val_loss: 1.1705	 val_acc: 0.6000
# step:72
# loss: 0.0092	 acc: 1.0000
# val_loss: 1.5325	 val_acc: 0.7000
# step:73
# loss: 0.0043	 acc: 1.0000
# val_loss: 1.6728	 val_acc: 0.7000
# step:74
# loss: 0.0032	 acc: 1.0000
# val_loss: 1.6397	 val_acc: 0.7000
# step:75
# loss: 0.0054	 acc: 1.0000
# val_loss: 1.4847	 val_acc: 0.6000
# step:76
# loss: 0.0040	 acc: 1.0000
# val_loss: 1.3678	 val_acc: 0.7000
# step:77
# loss: 0.0033	 acc: 1.0000
# val_loss: 1.2176	 val_acc: 0.7000
# step:78
# loss: 0.0027	 acc: 1.0000
# val_loss: 1.0463	 val_acc: 0.7000
# step:79
# loss: 0.0020	 acc: 1.0000
# val_loss: 0.9344	 val_acc: 0.7000
# step:80
# loss: 0.0019	 acc: 1.0000
# val_loss: 0.8249	 val_acc: 0.7000
# step:81
# loss: 0.0056	 acc: 1.0000
# val_loss: 0.9219	 val_acc: 0.7000
# step:82
# loss: 0.0019	 acc: 1.0000
# val_loss: 1.0383	 val_acc: 0.7000
# step:83
# loss: 0.0035	 acc: 1.0000
# val_loss: 1.1337	 val_acc: 0.7000
# step:84
# loss: 0.0025	 acc: 1.0000
# val_loss: 1.5582	 val_acc: 0.6000
# step:85
# loss: 0.0031	 acc: 1.0000
# val_loss: 2.1518	 val_acc: 0.6000
# step:86
# loss: 0.0079	 acc: 1.0000
# val_loss: 1.5755	 val_acc: 0.6000
# step:87
# loss: 0.0064	 acc: 1.0000
# val_loss: 1.1404	 val_acc: 0.7000
# step:88
# loss: 0.0084	 acc: 1.0000
# val_loss: 1.0922	 val_acc: 0.7000
# step:89
# loss: 0.0067	 acc: 1.0000
# val_loss: 1.0183	 val_acc: 0.7000
# step:90
# loss: 0.0070	 acc: 1.0000
# val_loss: 0.9651	 val_acc: 0.8000
# step:91
# loss: 0.0039	 acc: 1.0000
# val_loss: 1.0807	 val_acc: 0.7000
# step:92
# loss: 0.0038	 acc: 1.0000
# val_loss: 1.2729	 val_acc: 0.8000
# step:93
# loss: 0.0098	 acc: 1.0000
# val_loss: 1.6120	 val_acc: 0.6000
# step:94
# loss: 0.0124	 acc: 1.0000
# val_loss: 1.6039	 val_acc: 0.7000
# step:95
# loss: 0.0403	 acc: 0.9896
# val_loss: 1.3717	 val_acc: 0.6000
# step:96
# loss: 0.0174	 acc: 0.9948
# val_loss: 1.0790	 val_acc: 0.8000
# step:97
# loss: 0.0077	 acc: 1.0000
# val_loss: 0.9447	 val_acc: 0.6000
# step:98
# loss: 0.0102	 acc: 1.0000
# val_loss: 0.4119	 val_acc: 0.8000
# step:99
# loss: 0.0125	 acc: 1.0000
# val_loss: 0.3389	 val_acc: 0.9000
