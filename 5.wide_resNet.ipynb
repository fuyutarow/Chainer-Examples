# %%
from __future__ import print_function
import os

import pandas as pd
from PIL import Image
import numpy as np

import chainer
from chainer.dataset import convert
import chainer.links as L
import chainer.functions as F
from chainer import serializers

import utils
# Out:
# Using TensorFlow backend.
# /home/fytroo/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# ### ハイパーパラメータ

# %%
from easydict import EasyDict
args = EasyDict({
    'bs': 64, 
    'epoch' : 100,
    'lr' : 0.05,
    'gpu': 0,
    'out': 'result',
    'resume': '',
})
try:
    __file__.endswith('py')
    import argparse
    parser = argparse.ArgumentParser(description='Chainer example: MNIST')
    parser.add_argument('--batchsize', '-b', dest='bs', type=int, default=args.bs,
                        help='Number of images in each mini-batch')
    parser.add_argument('--epoch', '-e', type=int, default=args.epoch,
                        help='Number of sweeps over the dataset to train')
    parser.add_argument('--learningrate', '-l', dest='lr', type=float, default=args.lr,
                        help='Number of sweeps over the dataset to train')
    parser.add_argument('--frequency', '-f', type=int, default=-1,
                        help='Frequency of taking a snapshot')
    parser.add_argument('--gpu', '-g', type=int, default=args.gpu,
                        help='GPU ID (negative value indicates CPU)')
    parser.add_argument('--out', '-o', default=args.out,
                        help='Directory to output the result')
    parser.add_argument('--resume', '-r', default=args.resume,
                        help='Resume the training from snapshot')
    parser.add_argument('--unit', '-u', dest='n_in', type=int, default=args.n_in,
                        help='Number of units')
    parser.add_argument('--noplot', dest='plot', action='store_false',
                        help='Disable PlotReport extension')
    args = parser.parse_args()
except:
    print('no argsparse')
    pass
# Out:
# no argsparse

# %% [markdown]
# ### データセット読み込み

# %%
from chainer.datasets import get_cifar10

data_train, data_test = get_cifar10()

x_train = []
y_train = []
for i in range(data_train.__len__()):
    x, y = data_train.__getitem__(i)
    x_train.append(x)
    y_train.append(y)
x_train = np.array(x_train)
y_train = np.array(y_train)

x_test = []
y_test = []
for i in range(data_test.__len__()):
    x, y = data_test.__getitem__(i)
    x_test.append(x)
    y_test.append(y)
x_test = np.array(x_test)
y_test = np.array(y_test)

x_train = np.swapaxes(x_train*255, 1, 3).astype(np.uint8)
x_test = np.swapaxes(x_test*255, 1, 3).astype(np.uint8)

x_train.shape, x_train.dtype, x_test.dtype
# Out:
# ((50000, 32, 32, 3), dtype('uint8'), dtype('uint8'))

# %% [markdown]
# ### モデルを定義

# %%
class Block(chainer.Chain):
    def __init__(self, n_in=32, ch=16):
        super(Block, self).__init__()
        self.n_in = n_in
        self.ch = ch
        with self.init_scope():
            self.bn1 = L.BatchNormalization(n_in)
            self.conv1 = L.Convolution2D(None, ch, 1, 1, 0)
            self.bn2 = L.BatchNormalization(ch)
            self.conv2 = L.Convolution2D(None, ch, 1, 1, 0)
            self.bn3 = L.BatchNormalization(ch)
            
            self.conv = L.Convolution2D(None, ch, 1, 1, 0)
    
    def __call__(self, x):
        h = x_ = x
        h = self.bn1(h)
        h = self.conv1(h)
        h = self.bn2(h)
        h = F.relu(h)
        h = self.conv2(h)
        h = self.bn3(h)
        
        if self.n_in != self.ch:
            x_ = self.conv(x_)
        
        return h + x_

# %%
class Section(chainer.Chain):
    def __init__(self, n_in=32, ch=32, depth=1):
        super(Section, self).__init__()
        self.n_in = n_in
        self.ch = ch
        self.depth = depth
        with self.init_scope():
            exec('self.block{} = Block({}, {})'.format(0, n_in, ch))
            for i in range(1, self.depth):
                exec('self.block{} = Block({}, {})'.format(i, ch, ch))
    
    def __call__(self, x):
        for i in range(self.depth):
            x = eval('self.block{}'.format(i))(x)
        return x

# %%
class CNN(chainer.Chain):
    def __init__(self, n_in=32, n_out=10):
        super(CNN, self).__init__()
        with self.init_scope():
            self.conv1 = L.Convolution2D(None, 16, 3)
            self.section1 = Section(16, 16, 2)
            self.section2 = Section(16, 32, 2)
            self.section3 = Section(32, 64, 2)
            self.fc = L.Linear(None, n_out)
    
    def __call__(self, x):
        x = self.conv1(x)
        x = self.section1(x)
        print('#1', x.shape)
        x = F.average_pooling_2d(x, ksize=2, stride=2)
        x = self.section2(x)
        print('#2', x.shape)
        x = F.average_pooling_2d(x, ksize=2, stride=2)
        x = self.section3(x)
        print('#3', x.shape)
        x = F.average_pooling_2d(x, ksize=2, stride=2)
        x = self.fc(x)
        return x

# %%
n_label = np.unique(y_train).size
model = L.Classifier(CNN(n_label),
                    lossfun=F.softmax_cross_entropy,
                    accfun=F.accuracy)
xp = np
if args.gpu >= 0:
    import cupy as cp
    xp = cp
    chainer.cuda.get_device_from_id(args.gpu).use()
    model.to_gpu()  # Copy the model to the GPU
optimizer = chainer.optimizers.MomentumSGD(args.lr)
optimizer.setup(model)

# %% [markdown]
# ### data augmentation

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape

import Augmentor
p = Augmentor.Pipeline()
p.flip_left_right(probability=0.5)
p.flip_top_bottom(probability=0.5)
g = p.keras_generator_from_array(x_train, y_train, batch_size=args.bs)
g = ((
    xp.array(np.swapaxes((x/255.), 1, 3)).astype(np.float32),
    xp.array(y.astype(np.int8))
    ) for (x,y) in g)

# %% [markdown]
# chainer.trainingを使わず，訓練ループをかく
# chainer.trainingでは，自前のデータのイテレータを使うことができないため．
# Augmentorを使いたい

# %% [markdown]
# ### 訓練と検証

# %%
def train(step=None):
    total_loss = 0
    total_acc = 0
    n_data = 0
    n_train = len(y_train)
    for _ in range(n_train//args.bs):
        xs, ts = next(g) 
        x = chainer.Variable(xs)
        t = chainer.Variable(ts)
        optimizer.update(model, x, t)
        with chainer.using_config('train', True):
            loss = model(x,t)
        n_data += len(t.data)
        total_loss += float(loss.data) * len(t.data)
        total_acc += float(model.accuracy.data) * len(t.data)

    loss = total_loss / n_data
    acc = total_acc / n_data
    print('loss: {:.4f}\t acc: {:.4f}'.format(loss, acc))

def test(step=None):
    xs = xp.array(np.swapaxes((x_test), 1, 3)).astype(np.float32)
    ts = xp.array(y_test).astype(np.int8)
    x = chainer.Variable(xs)
    t = chainer.Variable(ts)
    loss = model(x,t)

    n_data = len(t.data)
    total_loss = float(loss.data) * len(t.data)
    total_acc = float(model.accuracy.data) * len(t.data)
    loss = total_loss / n_data
    acc = total_acc / n_data
    print('val_loss: {:.4f}\t val_acc: {:.4f}'.format(loss, acc))

# %%
if __name__ == '__main__':
    for step in range(args.epoch):
        print('step:{}'.format(step))
        train(step)
        test(step)
# Out:
# step:0
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# #1 (64, 16, 30, 30)
# #2 (64, 32, 15, 15)
# #3 (64, 64, 7, 7)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-363cff855476> in <module>()
#       2     for step in range(args.epoch):
#       3         print('step:{}'.format(step))
# ----> 4         train(step)
#       5         test(step)
#
# <ipython-input-9-d85dfc6b42a8> in train(step)
#       8         x = chainer.Variable(xs)
#       9         t = chainer.Variable(ts)
# ---> 10         optimizer.update(model, x, t)
#      11         with chainer.using_config('train', True):
#      12             loss = model(x,t)
#
# ~/anaconda3/lib/python3.6/site-packages/chainer/optimizer.py in update(self, lossfun, *args, **kwds)
#     537             else:
#     538                 self.target.zerograds()
# --> 539             loss.backward()
#     540             del loss
#     541
#
# ~/anaconda3/lib/python3.6/site-packages/chainer/variable.py in backward(self, retain_grad, enable_double_backprop)
#     850         """
#     851         with chainer.using_config('enable_backprop', enable_double_backprop):
# --> 852             self._backward_main(retain_grad)
#     853
#     854     def _backward_main(self, retain_grad):
#
# ~/anaconda3/lib/python3.6/site-packages/chainer/variable.py in _backward_main(self, retain_grad)
#     951
#     952             gxs = func.backward_accumulate(
# --> 953                 target_input_indexes, out_grad, in_grad)
#     954
#     955             assert len(gxs) == len(in_grad)
#
# ~/anaconda3/lib/python3.6/site-packages/chainer/function_node.py in backward_accumulate(self, target_input_indexes, grad_outputs, grad_inputs)
#     507         # The default implementation uses backward(). You can override this
#     508         # method without using backward().
# --> 509         gxs = self.backward(target_input_indexes, grad_outputs)
#     510
#     511         len_gxs = len(gxs)
#
# ~/anaconda3/lib/python3.6/site-packages/chainer/functions/normalization/batch_normalization.py in backward(self, indexes, grad_outputs)
#     126             self.eps, self.use_cudnn, self.mode, self.expander, self.axis,
#     127             self.mean, self.inv_std)
# --> 128         return f(x, gamma, gy)
#     129
#     130
#
# ~/anaconda3/lib/python3.6/site-packages/chainer/function.py in __call__(self, *inputs)
#     224         self._owned_node = None
#     225
# --> 226         ret = node.apply(inputs)
#     227
#     228         if len(ret) == 1:
#
# ~/anaconda3/lib/python3.6/site-packages/chainer/function_node.py in apply(self, inputs)
#     242             self._output_indexes_to_retain = None
#     243             outputs = self.forward(in_data)
# --> 244             assert type(outputs) is tuple
#     245
#     246         for hook in hooks:
#
# KeyboardInterrupt:
