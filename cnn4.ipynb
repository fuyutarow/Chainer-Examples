# %%
from __future__ import print_function
import os

import pandas as pd
from PIL import Image
import numpy as np

import chainer
from chainer.dataset import convert
import chainer.links as L
import chainer.functions as F
from chainer import serializers

from chainer.datasets import get_cifar10
from chainer.datasets import get_cifar100

import utils
# Out:
# Using TensorFlow backend.
# /home/fytroo/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# ### ハイパーパラメータ

# %%
from easydict import EasyDict
args = EasyDict({
    'bs': 64, 
    'epoch' : 100,
    'lr' : 0.05,
    'gpu': 0,
    'out': 'result',
    'resume': '',
    'n_in': 32, 
})
try:
    __file__.endswith('py')
    import argparse
    parser = argparse.ArgumentParser(description='Chainer example: MNIST')
    parser.add_argument('--batchsize', '-b', dest='bs', type=int, default=args.bs,
                        help='Number of images in each mini-batch')
    parser.add_argument('--epoch', '-e', type=int, default=args.epoch,
                        help='Number of sweeps over the dataset to train')
    parser.add_argument('--learningrate', '-l', dest='lr', type=float, default=args.lr,
                        help='Number of sweeps over the dataset to train')
    parser.add_argument('--frequency', '-f', type=int, default=-1,
                        help='Frequency of taking a snapshot')
    parser.add_argument('--gpu', '-g', type=int, default=args.gpu,
                        help='GPU ID (negative value indicates CPU)')
    parser.add_argument('--out', '-o', default=args.out,
                        help='Directory to output the result')
    parser.add_argument('--resume', '-r', default=args.resume,
                        help='Resume the training from snapshot')
    parser.add_argument('--unit', '-u', dest='n_in', type=int, default=args.n_in,
                        help='Number of units')
    parser.add_argument('--noplot', dest='plot', action='store_false',
                        help='Disable PlotReport extension')
    args = parser.parse_args()
except:
    print('no argsparse')
    pass
# Out:
# no argsparse

# %% [markdown]
# ### データセット読み込み

# %%
dataset_dir = 'flower_images'
df  = pd.DataFrame.from_csv(os.path.join(dataset_dir,'flower_labels.csv'))

df['name'] = df.index
df['path'] = dataset_dir + '/' + df['name']

n_label = df.label.drop_duplicates().count()
n_label
df
# Out:
# /home/fytroo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#           label      name                    path
# file
# 0001.png      0  0001.png  flower_images/0001.png
# 0002.png      0  0002.png  flower_images/0002.png
# 0003.png      2  0003.png  flower_images/0003.png
# 0004.png      0  0004.png  flower_images/0004.png
# 0005.png      0  0005.png  flower_images/0005.png
# 0006.png      1  0006.png  flower_images/0006.png
# 0007.png      6  0007.png  flower_images/0007.png
# 0008.png      0  0008.png  flower_images/0008.png
# 0009.png      0  0009.png  flower_images/0009.png
# 0010.png      0  0010.png  flower_images/0010.png
# 0011.png      0  0011.png  flower_images/0011.png
# 0012.png      0  0012.png  flower_images/0012.png
# 0013.png      0  0013.png  flower_images/0013.png
# 0014.png      7  0014.png  flower_images/0014.png
# 0015.png      7  0015.png  flower_images/0015.png
# 0016.png      1  0016.png  flower_images/0016.png
# 0017.png      0  0017.png  flower_images/0017.png
# 0018.png      0  0018.png  flower_images/0018.png
# 0019.png      6  0019.png  flower_images/0019.png
# 0020.png      0  0020.png  flower_images/0020.png
# 0021.png      2  0021.png  flower_images/0021.png
# 0022.png      4  0022.png  flower_images/0022.png
# 0023.png      7  0023.png  flower_images/0023.png
# 0024.png      4  0024.png  flower_images/0024.png
# 0025.png      5  0025.png  flower_images/0025.png
# 0026.png      6  0026.png  flower_images/0026.png
# 0027.png      2  0027.png  flower_images/0027.png
# 0028.png      5  0028.png  flower_images/0028.png
# 0029.png      6  0029.png  flower_images/0029.png
# 0030.png      6  0030.png  flower_images/0030.png
# ...         ...       ...                     ...
# 0181.png      0  0181.png  flower_images/0181.png
# 0182.png      5  0182.png  flower_images/0182.png
# 0183.png      8  0183.png  flower_images/0183.png
# 0184.png      6  0184.png  flower_images/0184.png
# 0185.png      3  0185.png  flower_images/0185.png
# 0186.png      9  0186.png  flower_images/0186.png
# 0187.png      6  0187.png  flower_images/0187.png
# 0188.png      1  0188.png  flower_images/0188.png
# 0189.png      3  0189.png  flower_images/0189.png
# 0190.png      7  0190.png  flower_images/0190.png
# 0191.png      4  0191.png  flower_images/0191.png
# 0192.png      7  0192.png  flower_images/0192.png
# 0193.png      1  0193.png  flower_images/0193.png
# 0194.png      9  0194.png  flower_images/0194.png
# 0195.png      8  0195.png  flower_images/0195.png
# 0196.png      3  0196.png  flower_images/0196.png
# 0197.png      6  0197.png  flower_images/0197.png
# 0198.png      5  0198.png  flower_images/0198.png
# 0199.png      6  0199.png  flower_images/0199.png
# 0200.png      4  0200.png  flower_images/0200.png
# 0201.png      1  0201.png  flower_images/0201.png
# 0202.png      3  0202.png  flower_images/0202.png
# 0203.png      8  0203.png  flower_images/0203.png
# 0204.png      5  0204.png  flower_images/0204.png
# 0205.png      4  0205.png  flower_images/0205.png
# 0206.png      6  0206.png  flower_images/0206.png
# 0207.png      0  0207.png  flower_images/0207.png
# 0208.png      4  0208.png  flower_images/0208.png
# 0209.png      6  0209.png  flower_images/0209.png
# 0210.png      1  0210.png  flower_images/0210.png
#
# [210 rows x 3 columns]

# %%
def load_fromdf(dataframe, resize=(96,96)):
    if type(resize) is int:
        resize = (resize, resize)
    
    df = dataframe
    x_data = []
    y_data = []
    for idx, row in df.iterrows():
        y = row['label']
        f = row['path']

        img = Image.open(f).resize(resize, Image.LANCZOS)
        img = img.convert('RGB')
        x = np.array(img)
        x_data.append(x)
        y_data.append(y)
    x_data = np.array(x_data)
    y_data = np.array(y_data)

    return x_data, y_data

# %%
df_train, df_test = utils.train_test_split_df(df, test_size=0.1)
x_train, y_train = load_fromdf(df_train, resize=args.n_in)
x_test, y_test = load_fromdf(df_test, resize=args.n_in)

x_train.shape
# Out:
# (200, 32, 32, 3)

# %% [markdown]
# ### モデルを定義

# %%
class Fire(chainer.Chain):
    def __init__(self, n_in=None, width=32, depth=1):
        super(Fire, self).__init__()
        self.depth = depth
        with self.init_scope():
            for i in range(self.depth):
                exec('self.conv{id} = L.Convolution2D(None, {channel}, 1, 1, 0)'.format(id=i, channel=width))
                exec('self.bn{id} = L.BatchNormalization({channel})'.format(id=i, channel=width))
    
    def __call__(self, x):
        for i in range(self.depth):
            h = x
            h = eval('self.bn{}'.format(i))(h)
            h = F.relu(h)
            h = eval('self.conv{}'.format(i))(h)
            #x = h + x
            x = h
        return x

# %%
class Block(chainer.Chain):
    def __init__(self, n_in=32, n_out=32, width=16, depth=1):
        super(Block, self).__init__()
        self.n_in = n_in
        self.n_out = n_out
        self.depth = depth
        ch = width
        with self.init_scope():
            self.bn1 = L.BatchNormalization(n_in)
            self.conv1 = L.Convolution2D(None, ch, 1, 1, 0)
            self.bn2 = L.BatchNormalization(ch)
            self.conv2 = L.Convolution2D(None, ch, 1, 1, 0)
            self.bn3 = L.BatchNormalization(ch)
            self.conv3 = L.Convolution2D(None, n_out, 1, 1, 0)
            
            self.conv = L.Convolution2D(None, n_out, 1, 1, 0)
    
    def __call__(self, x):
        h = _x = x
        
        h = self.bn1(h)
        h = F.relu(h)
        h = self.conv1(h)
        h = self.bn2(h)
        h = F.relu(h)
        h = self.conv2(h)
        h = self.bn3(h)
        h = F.relu(h)
        h = self.conv3(h)
        print('#################',h.shape, x.shape)
        if self.n_out != self.n_in:
            _x = self.conv(_x)
            
        x = h + _x
        return x

# %%
class LeNet(chainer.Chain):
    def __init__(self, n_in=32, n_out=10):
        super(LeNet, self).__init__()
        with self.init_scope():
            self.conv1 = L.Convolution2D(None, 32, 3)
            self.block1 = Block(32, 32, width=32, depth=2)
            self.block2 = Block(32, 32, width=32, depth=2)
            self.fc = L.Linear(None, n_out)
    
    def __call__(self, x):
        x = self.conv1(x)
        #x = F.dropout(x, 0.25)
        x = self.block1(x)
        x = F.max_pooling_2d(x, ksize=2, stride=2)
        #x = F.dropout(x, 0.25)
        x = self.block2(x)
        #x = F.dropout(x, 0.25)
        x = F.average_pooling_2d(x, ksize=2, stride=2)
        x = self.fc(x)
        return x

# %%
class Block(chainer.Chain):
    def __init__(self, n_in=32, n_out=32, width=16, depth=1):
        super(Block, self).__init__()
        self.n_in = n_in
        self.n_out = n_out
        self.depth = depth
        ch = width
        with self.init_scope():
            self.bn1 = L.BatchNormalization(n_in)
            self.conv1 = L.Convolution2D(None, ch, 1, 1, 0)
            self.bn2 = L.BatchNormalization(ch)
            self.conv2 = L.Convolution2D(None, ch, 1, 1, 0)
            self.bn3 = L.BatchNormalization(ch)
            self.conv4 = L.Convolution2D(None, n_out, 1, 1, 0)
            self.conv = L.Convolution2D(n_in, n_out, 1, 1, 0)
    
    def __call__(self, x):
        h = x_ = x
        h = self.bn1(h)
        h = F.relu(h)
        h = self.conv1(h)
        h = self.bn2(h)
        h = F.relu(h)
        h = self.conv2(h)
        h = self.bn3(h)
        h = F.relu(h)
        h = self.conv3(h)
        
        if self.n_out != self.n_in: 
            x_ = self.conv(x_) 
        x = h #+ x_
        return x

# %%
class LeNet(chainer.Chain):
    def __init__(self, n_in=32, n_out=10):
        super(LeNet, self).__init__()
        with self.init_scope():
            self.conv1 = L.Convolution2D(None, 32, 3)
            self.block1 = Block(32, 16, width=32, depth=2)
            self.block2 = Block(16, 8, width=64, depth=2)
            self.fc = L.Linear(None, n_out)
    
    def __call__(self, x):
        x = self.conv1(x)
        #x = F.dropout(x, 0.25)
        x = self.block1(x)
        x = F.max_pooling_2d(x, ksize=2, stride=2)
        #x = F.dropout(x, 0.25)
        x = self.block2(x)
        #x = F.dropout(x, 0.25)
        x = F.average_pooling_2d(x, ksize=2, stride=2)
        x = self.fc(x)
        return x

# %%
model = L.Classifier(LeNet(args.n_in, n_label),
                    lossfun=F.softmax_cross_entropy,
                    accfun=F.accuracy)
xp = np
if args.gpu >= 0:
    import cupy as cp
    xp = cp
    chainer.cuda.get_device_from_id(args.gpu).use()
    model.to_gpu()  # Copy the model to the GPU
optimizer = chainer.optimizers.MomentumSGD(args.lr)
optimizer.setup(model)

# %% [markdown]
# ### data augmentation

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape

import Augmentor
p = Augmentor.Pipeline()
p.flip_left_right(probability=0.5)
p.flip_top_bottom(probability=0.5)
g = p.keras_generator_from_array(x_train, y_train, batch_size=args.bs)
g = ((
    xp.array(np.swapaxes((x/255.), 1, 3)).astype(np.float32),
    xp.array(y.astype(np.int8))
    ) for (x,y) in g)

# %% [markdown]
# chainer.trainingを使わず，訓練ループをかく
# chainer.trainingでは，自前のデータのイテレータを使うことができないため．
# Augmentorを使いたい

# %% [markdown]
# ### 訓練と検証

# %%
def train(step=None):
    total_loss = 0
    total_acc = 0
    n_data = 0
    n_train = len(y_train)
    for _ in range(n_train//args.bs):
        xs, ts = next(g) 
        x = chainer.Variable(xs)
        t = chainer.Variable(ts)
        optimizer.update(model, x, t)
        with chainer.using_config('train', True):
            loss = model(x,t)
        n_data += len(t.data)
        total_loss += float(loss.data) * len(t.data)
        total_acc += float(model.accuracy.data) * len(t.data)

    loss = total_loss / n_data
    acc = total_acc / n_data
    print('loss: {:.4f}\t acc: {:.4f}'.format(loss, acc))

def test(step=None):
    xs = xp.array(np.swapaxes((x_test), 1, 3)).astype(np.float32)
    ts = xp.array(y_test).astype(np.int8)
    x = chainer.Variable(xs)
    t = chainer.Variable(ts)
    loss = model(x,t)

    n_data = len(t.data)
    total_loss = float(loss.data) * len(t.data)
    total_acc = float(model.accuracy.data) * len(t.data)
    loss = total_loss / n_data
    acc = total_acc / n_data
    print('val_loss: {:.4f}\t val_acc: {:.4f}'.format(loss, acc))

# %%
if __name__ == '__main__':
    for step in range(args.epoch):
        print('step:{}'.format(step))
        train(step)
        test(step)
# Out:
# step:0
# loss: 2.0207	 acc: 0.3021
# val_loss: 2.2508	 val_acc: 0.3000
# step:1
# loss: 1.5628	 acc: 0.5000
# val_loss: 1.9644	 val_acc: 0.4000
# step:2
# loss: 1.2535	 acc: 0.6094
# val_loss: 1.7480	 val_acc: 0.5000
# step:3
# loss: 0.9336	 acc: 0.6979
# val_loss: 1.2453	 val_acc: 0.5000
# step:4
# loss: 0.8368	 acc: 0.7083
# val_loss: 0.8406	 val_acc: 0.6000
# step:5
# loss: 0.7272	 acc: 0.7135
# val_loss: 1.3402	 val_acc: 0.5000
# step:6
# loss: 0.6278	 acc: 0.8073
# val_loss: 1.3935	 val_acc: 0.5000
# step:7
# loss: 0.6548	 acc: 0.7500
# val_loss: 2.2145	 val_acc: 0.4000
# step:8
# loss: 0.7191	 acc: 0.7812
# val_loss: 1.6656	 val_acc: 0.6000
# step:9
# loss: 0.7867	 acc: 0.7604
# val_loss: 1.9713	 val_acc: 0.5000
# step:10
# loss: 1.0393	 acc: 0.6615
# val_loss: 1.6964	 val_acc: 0.4000
# step:11
# loss: 0.7778	 acc: 0.7500
# val_loss: 2.5483	 val_acc: 0.5000
# step:12
# loss: 0.9272	 acc: 0.7552
# val_loss: 1.5689	 val_acc: 0.5000
# step:13
# loss: 0.7447	 acc: 0.7552
# val_loss: 0.8285	 val_acc: 0.7000
# step:14
# loss: 0.5363	 acc: 0.8073
# val_loss: 1.2232	 val_acc: 0.6000
# step:15
# loss: 0.4942	 acc: 0.8281
# val_loss: 1.2096	 val_acc: 0.7000
# step:16
# loss: 0.6356	 acc: 0.7917
# val_loss: 0.6824	 val_acc: 0.9000
# step:17
# loss: 0.4113	 acc: 0.8385
# val_loss: 1.1157	 val_acc: 0.8000
# step:18
# loss: 0.3672	 acc: 0.8646
# val_loss: 1.1418	 val_acc: 0.6000
# step:19
# loss: 0.3174	 acc: 0.9115
# val_loss: 1.1909	 val_acc: 0.5000
# step:20
# loss: 0.2285	 acc: 0.9219
# val_loss: 0.9720	 val_acc: 0.7000
# step:21
# loss: 0.3452	 acc: 0.9219
# val_loss: 1.3033	 val_acc: 0.7000
# step:22
# loss: 0.2257	 acc: 0.9375
# val_loss: 0.9063	 val_acc: 0.8000
# step:23
# loss: 0.2601	 acc: 0.9062
# val_loss: 0.9279	 val_acc: 0.6000
# step:24
# loss: 0.1993	 acc: 0.9427
# val_loss: 0.9983	 val_acc: 0.8000
# step:25
# loss: 0.3528	 acc: 0.9010
# val_loss: 0.9684	 val_acc: 0.9000
# step:26
# loss: 0.2287	 acc: 0.9323
# val_loss: 1.3330	 val_acc: 0.7000
# step:27
# loss: 0.2308	 acc: 0.9062
# val_loss: 0.9532	 val_acc: 0.7000
# step:28
# loss: 0.2072	 acc: 0.9167
# val_loss: 1.4669	 val_acc: 0.8000
# step:29
# loss: 0.2353	 acc: 0.9167
# val_loss: 0.7174	 val_acc: 0.8000
# step:30
# loss: 0.2933	 acc: 0.9167
# val_loss: 1.0020	 val_acc: 0.7000
# step:31
# loss: 0.2531	 acc: 0.9062
# val_loss: 1.3384	 val_acc: 0.7000
# step:32
# loss: 0.1851	 acc: 0.9323
# val_loss: 0.9669	 val_acc: 0.6000
# step:33
# loss: 0.2480	 acc: 0.9062
# val_loss: 1.0526	 val_acc: 0.7000
# step:34
# loss: 0.2163	 acc: 0.9167
# val_loss: 1.9317	 val_acc: 0.6000
# step:35
# loss: 0.2392	 acc: 0.9062
# val_loss: 1.5879	 val_acc: 0.7000
# step:36
# loss: 0.1426	 acc: 0.9375
# val_loss: 0.6854	 val_acc: 0.9000
# step:37
# loss: 0.1258	 acc: 0.9635
# val_loss: 0.8773	 val_acc: 0.7000
# step:38
# loss: 0.1170	 acc: 0.9531
# val_loss: 0.8326	 val_acc: 0.8000
# step:39
# loss: 0.0992	 acc: 0.9583
# val_loss: 1.0798	 val_acc: 0.8000
# step:40
# loss: 0.1704	 acc: 0.9479
# val_loss: 0.7347	 val_acc: 0.9000
# step:41
# loss: 0.1059	 acc: 0.9792
# val_loss: 0.9280	 val_acc: 0.9000
# step:42
# loss: 0.1006	 acc: 0.9740
# val_loss: 1.1877	 val_acc: 0.9000
# step:43
# loss: 0.0652	 acc: 0.9688
# val_loss: 1.0849	 val_acc: 0.9000
# step:44
# loss: 0.0626	 acc: 0.9844
# val_loss: 0.8681	 val_acc: 0.9000
# step:45
# loss: 0.0471	 acc: 0.9896
# val_loss: 0.9741	 val_acc: 0.8000
# step:46
# loss: 0.0243	 acc: 0.9896
# val_loss: 1.5312	 val_acc: 0.7000
# step:47
# loss: 0.0679	 acc: 0.9844
# val_loss: 1.7621	 val_acc: 0.7000
# step:48
# loss: 0.0771	 acc: 0.9844
# val_loss: 1.0444	 val_acc: 0.8000
# step:49
# loss: 0.0211	 acc: 1.0000
# val_loss: 1.0299	 val_acc: 0.6000
# step:50
# loss: 0.0401	 acc: 0.9948
# val_loss: 0.9211	 val_acc: 0.7000
# step:51
# loss: 0.0567	 acc: 0.9844
# val_loss: 1.2340	 val_acc: 0.6000
# step:52
# loss: 0.0445	 acc: 0.9896
# val_loss: 1.0219	 val_acc: 0.7000
# step:53
# loss: 0.0448	 acc: 0.9844
# val_loss: 1.4299	 val_acc: 0.6000
# step:54
# loss: 0.0295	 acc: 0.9896
# val_loss: 1.3598	 val_acc: 0.7000
# step:55
# loss: 0.0748	 acc: 0.9792
# val_loss: 1.2920	 val_acc: 0.8000
# step:56
# loss: 0.0834	 acc: 0.9740
# val_loss: 1.0963	 val_acc: 0.7000
# step:57
# loss: 0.0523	 acc: 0.9844
# val_loss: 1.7336	 val_acc: 0.6000
# step:58
# loss: 0.0581	 acc: 0.9896
# val_loss: 1.6254	 val_acc: 0.6000
# step:59
# loss: 0.0284	 acc: 0.9948
# val_loss: 1.6995	 val_acc: 0.6000
# step:60
# loss: 0.0485	 acc: 0.9896
# val_loss: 2.0990	 val_acc: 0.7000
# step:61
# loss: 0.0454	 acc: 0.9948
# val_loss: 1.8445	 val_acc: 0.8000
# step:62
# loss: 0.0275	 acc: 0.9948
# val_loss: 1.7305	 val_acc: 0.8000
# step:63
# loss: 0.0156	 acc: 1.0000
# val_loss: 1.6337	 val_acc: 0.8000
# step:64
# loss: 0.0196	 acc: 0.9948
# val_loss: 1.6315	 val_acc: 0.7000
# step:65
# loss: 0.0408	 acc: 0.9896
# val_loss: 1.7884	 val_acc: 0.7000
# step:66
# loss: 0.0204	 acc: 0.9948
# val_loss: 1.9153	 val_acc: 0.7000
# step:67
# loss: 0.0120	 acc: 1.0000
# val_loss: 1.9323	 val_acc: 0.8000
# step:68
# loss: 0.0294	 acc: 1.0000
# val_loss: 2.1242	 val_acc: 0.7000
# step:69
# loss: 0.0719	 acc: 0.9896
# val_loss: 2.0697	 val_acc: 0.7000
# step:70
# loss: 0.0168	 acc: 1.0000
# val_loss: 2.3056	 val_acc: 0.7000
# step:71
# loss: 0.0176	 acc: 1.0000
# val_loss: 2.3285	 val_acc: 0.7000
# step:72
# loss: 0.0227	 acc: 1.0000
# val_loss: 2.0115	 val_acc: 0.7000
# step:73
# loss: 0.0231	 acc: 1.0000
# val_loss: 1.7515	 val_acc: 0.7000
# step:74
# loss: 0.0213	 acc: 0.9948
# val_loss: 1.1617	 val_acc: 0.8000
# step:75
# loss: 0.0260	 acc: 0.9844
# val_loss: 1.3656	 val_acc: 0.8000
# step:76
# loss: 0.0209	 acc: 0.9896
# val_loss: 1.5679	 val_acc: 0.7000
# step:77
# loss: 0.0216	 acc: 0.9948
# val_loss: 1.2652	 val_acc: 0.7000
# step:78
# loss: 0.0453	 acc: 0.9896
# val_loss: 1.6151	 val_acc: 0.8000
# step:79
# loss: 0.0286	 acc: 0.9896
# val_loss: 1.8225	 val_acc: 0.8000
# step:80
# loss: 0.0119	 acc: 1.0000
# val_loss: 1.9603	 val_acc: 0.7000
# step:81
# loss: 0.0120	 acc: 1.0000
# val_loss: 1.8473	 val_acc: 0.7000
# step:82
# loss: 0.0232	 acc: 0.9948
# val_loss: 2.0179	 val_acc: 0.6000
# step:83
# loss: 0.0096	 acc: 1.0000
# val_loss: 2.5343	 val_acc: 0.5000
# step:84
# loss: 0.0159	 acc: 1.0000
# val_loss: 2.2174	 val_acc: 0.8000
# step:85
# loss: 0.0142	 acc: 1.0000
# val_loss: 2.1248	 val_acc: 0.8000
# step:86
# loss: 0.0146	 acc: 0.9948
# val_loss: 1.9424	 val_acc: 0.8000
# step:87
# loss: 0.0075	 acc: 1.0000
# val_loss: 1.7527	 val_acc: 0.8000
# step:88
# loss: 0.0044	 acc: 1.0000
# val_loss: 1.6940	 val_acc: 0.8000
# step:89
# loss: 0.0106	 acc: 1.0000
# val_loss: 1.5353	 val_acc: 0.8000
# step:90
# loss: 0.0033	 acc: 1.0000
# val_loss: 1.4244	 val_acc: 0.7000
# step:91
# loss: 0.0075	 acc: 1.0000
# val_loss: 1.4779	 val_acc: 0.7000
# step:92
# loss: 0.0091	 acc: 1.0000
# val_loss: 1.1416	 val_acc: 0.8000
# step:93
# loss: 0.0051	 acc: 1.0000
# val_loss: 1.1139	 val_acc: 0.9000
# step:94
# loss: 0.0058	 acc: 1.0000
# val_loss: 1.0651	 val_acc: 0.9000
# step:95
# loss: 0.0052	 acc: 1.0000
# val_loss: 0.9965	 val_acc: 0.9000
# step:96
# loss: 0.0038	 acc: 1.0000
# val_loss: 0.9231	 val_acc: 0.9000
# step:97
# loss: 0.0025	 acc: 1.0000
# val_loss: 0.8706	 val_acc: 0.9000
# step:98
# loss: 0.0068	 acc: 1.0000
# val_loss: 0.8302	 val_acc: 0.9000
# step:99
# loss: 0.0014	 acc: 1.0000
# val_loss: 0.8086	 val_acc: 0.9000
