# %%
from __future__ import print_function
import os

import pandas as pd
from PIL import Image
import numpy as np

import chainer
from chainer.dataset import convert
import chainer.links as L
import chainer.functions as F
from chainer import serializers

from chainer.datasets import get_cifar10
from chainer.datasets import get_cifar100

import utils
# Out:
# Using TensorFlow backend.
# /home/fytroo/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# ### ハイパーパラメータ

# %%
from easydict import EasyDict
args = EasyDict({
    'bs': 64, 
    'epoch' : 100,
    'lr' : 0.05,
    'gpu': 0,
    'out': 'result',
    'resume': '',
    'n_in': 32, 
})
try:
    __file__.endswith('py')
    import argparse
    parser = argparse.ArgumentParser(description='Chainer example: MNIST')
    parser.add_argument('--batchsize', '-b', dest='bs', type=int, default=args.bs,
                        help='Number of images in each mini-batch')
    parser.add_argument('--epoch', '-e', type=int, default=args.epoch,
                        help='Number of sweeps over the dataset to train')
    parser.add_argument('--learningrate', '-l', dest='lr', type=float, default=args.lr,
                        help='Number of sweeps over the dataset to train')
    parser.add_argument('--frequency', '-f', type=int, default=-1,
                        help='Frequency of taking a snapshot')
    parser.add_argument('--gpu', '-g', type=int, default=args.gpu,
                        help='GPU ID (negative value indicates CPU)')
    parser.add_argument('--out', '-o', default=args.out,
                        help='Directory to output the result')
    parser.add_argument('--resume', '-r', default=args.resume,
                        help='Resume the training from snapshot')
    parser.add_argument('--unit', '-u', dest='n_in', type=int, default=args.n_in,
                        help='Number of units')
    parser.add_argument('--noplot', dest='plot', action='store_false',
                        help='Disable PlotReport extension')
    args = parser.parse_args()
except:
    print('no argsparse')
    pass
# Out:
# no argsparse

# %% [markdown]
# ### データセット読み込み

# %%
dataset_dir = 'flower_images'
df  = pd.DataFrame.from_csv(os.path.join(dataset_dir,'flower_labels.csv'))

df['name'] = df.index
df['path'] = dataset_dir + '/' + df['name']

n_label = df.label.drop_duplicates().count()
n_label
df
# Out:
# /home/fytroo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#           label      name                    path
# file
# 0001.png      0  0001.png  flower_images/0001.png
# 0002.png      0  0002.png  flower_images/0002.png
# 0003.png      2  0003.png  flower_images/0003.png
# 0004.png      0  0004.png  flower_images/0004.png
# 0005.png      0  0005.png  flower_images/0005.png
# 0006.png      1  0006.png  flower_images/0006.png
# 0007.png      6  0007.png  flower_images/0007.png
# 0008.png      0  0008.png  flower_images/0008.png
# 0009.png      0  0009.png  flower_images/0009.png
# 0010.png      0  0010.png  flower_images/0010.png
# 0011.png      0  0011.png  flower_images/0011.png
# 0012.png      0  0012.png  flower_images/0012.png
# 0013.png      0  0013.png  flower_images/0013.png
# 0014.png      7  0014.png  flower_images/0014.png
# 0015.png      7  0015.png  flower_images/0015.png
# 0016.png      1  0016.png  flower_images/0016.png
# 0017.png      0  0017.png  flower_images/0017.png
# 0018.png      0  0018.png  flower_images/0018.png
# 0019.png      6  0019.png  flower_images/0019.png
# 0020.png      0  0020.png  flower_images/0020.png
# 0021.png      2  0021.png  flower_images/0021.png
# 0022.png      4  0022.png  flower_images/0022.png
# 0023.png      7  0023.png  flower_images/0023.png
# 0024.png      4  0024.png  flower_images/0024.png
# 0025.png      5  0025.png  flower_images/0025.png
# 0026.png      6  0026.png  flower_images/0026.png
# 0027.png      2  0027.png  flower_images/0027.png
# 0028.png      5  0028.png  flower_images/0028.png
# 0029.png      6  0029.png  flower_images/0029.png
# 0030.png      6  0030.png  flower_images/0030.png
# ...         ...       ...                     ...
# 0181.png      0  0181.png  flower_images/0181.png
# 0182.png      5  0182.png  flower_images/0182.png
# 0183.png      8  0183.png  flower_images/0183.png
# 0184.png      6  0184.png  flower_images/0184.png
# 0185.png      3  0185.png  flower_images/0185.png
# 0186.png      9  0186.png  flower_images/0186.png
# 0187.png      6  0187.png  flower_images/0187.png
# 0188.png      1  0188.png  flower_images/0188.png
# 0189.png      3  0189.png  flower_images/0189.png
# 0190.png      7  0190.png  flower_images/0190.png
# 0191.png      4  0191.png  flower_images/0191.png
# 0192.png      7  0192.png  flower_images/0192.png
# 0193.png      1  0193.png  flower_images/0193.png
# 0194.png      9  0194.png  flower_images/0194.png
# 0195.png      8  0195.png  flower_images/0195.png
# 0196.png      3  0196.png  flower_images/0196.png
# 0197.png      6  0197.png  flower_images/0197.png
# 0198.png      5  0198.png  flower_images/0198.png
# 0199.png      6  0199.png  flower_images/0199.png
# 0200.png      4  0200.png  flower_images/0200.png
# 0201.png      1  0201.png  flower_images/0201.png
# 0202.png      3  0202.png  flower_images/0202.png
# 0203.png      8  0203.png  flower_images/0203.png
# 0204.png      5  0204.png  flower_images/0204.png
# 0205.png      4  0205.png  flower_images/0205.png
# 0206.png      6  0206.png  flower_images/0206.png
# 0207.png      0  0207.png  flower_images/0207.png
# 0208.png      4  0208.png  flower_images/0208.png
# 0209.png      6  0209.png  flower_images/0209.png
# 0210.png      1  0210.png  flower_images/0210.png
#
# [210 rows x 3 columns]

# %%
def load_fromdf(dataframe, resize=(96,96)):
    if type(resize) is int:
        resize = (resize, resize)
    
    df = dataframe
    x_data = []
    y_data = []
    for idx, row in df.iterrows():
        y = row['label']
        f = row['path']

        img = Image.open(f).resize(resize, Image.LANCZOS)
        img = img.convert('RGB')
        x = np.array(img)
        x_data.append(x)
        y_data.append(y)
    x_data = np.array(x_data)
    y_data = np.array(y_data)

    return x_data, y_data

# %%
df_train, df_test = utils.train_test_split_df(df, test_size=0.1)
x_train, y_train = load_fromdf(df_train, resize=args.n_in)
x_test, y_test = load_fromdf(df_test, resize=args.n_in)

x_train.shape, x_train.dtype, y_train.dtype
# Out:
# ((200, 32, 32, 3), dtype('uint8'), dtype('int64'))

# %%
x_train.dtype, y_train.dtype
# Out:
# (dtype('uint8'), dtype('int64'))

# %% [markdown]
# ### モデルを定義

# %%
class Fire(chainer.Chain):
    def __init__(self, n_in=None, n_out=32, depth=1):
        super(Fire, self).__init__()
        with self.init_scope():
            self.conv1 = L.Convolution2D(n_in, 32, 3)
            self.conv2 = L.Convolution2D(None, n_out, 3)
            self.bn = L.BatchNormalization(32)
            self.bn2 = L.BatchNormalization(32)
            self.bn3 = L.BatchNormalization(32)
    
    def __call__(self, x):
        x = self.bn(x)
        x = self.conv1(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = self.bn3(x)
        return x

# %%
class LeNet(chainer.Chain):
    def __init__(self, n_in=32, n_out=10):
        super(LeNet, self).__init__()
        with self.init_scope():
            self.conv1 = L.Convolution2D(None, 32, 3)
            self.fire1 = Fire(None, 32, depth=2)
            self.fire2 = Fire(None, 32, depth=2)
            self.fc = L.Linear(None, n_out)
    
    def __call__(self, x):
        x = self.conv1(x)
        #x = F.dropout(x, 0.25)
        x = self.fire1(x)
        #x = F.dropout(x, 0.25)
        x = self.fire2(x)
        #x = F.dropout(x, 0.25)
        x = F.average_pooling_2d(x, ksize=2, stride=2)
        x = self.fc(x)
        return x

# %%
model = L.Classifier(LeNet(args.n_in, n_label),
                    lossfun=F.softmax_cross_entropy,
                    accfun=F.accuracy)
xp = np
if args.gpu >= 0:
    import cupy as cp
    xp = cp
    chainer.cuda.get_device_from_id(args.gpu).use()
    model.to_gpu()  # Copy the model to the GPU
optimizer = chainer.optimizers.MomentumSGD(args.lr)
optimizer.setup(model)

# %% [markdown]
# ### data augmentation

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape

import Augmentor
p = Augmentor.Pipeline()
p.flip_left_right(probability=0.5)
p.flip_top_bottom(probability=0.5)
g = p.keras_generator_from_array(x_train, y_train, batch_size=args.bs)
g = ((
    xp.array(np.swapaxes((x/255.), 1, 3)).astype(np.float32),
    xp.array(y.astype(np.int8))
    ) for (x,y) in g)

# %% [markdown]
# chainer.trainingを使わず，訓練ループをかく
# chainer.trainingでは，自前のデータのイテレータを使うことができないため．
# Augmentorを使いたい

# %% [markdown]
# ### 訓練と検証

# %%
def train(step=None):
    total_loss = 0
    total_acc = 0
    n_data = 0
    n_train = len(y_train)
    for _ in range(n_train//args.bs):
        xs, ts = next(g) 
        x = chainer.Variable(xs)
        t = chainer.Variable(ts)
        optimizer.update(model, x, t)
        with chainer.using_config('train', True):
            loss = model(x,t)
        n_data += len(t.data)
        total_loss += float(loss.data) * len(t.data)
        total_acc += float(model.accuracy.data) * len(t.data)

    loss = total_loss / n_data
    acc = total_acc / n_data
    print('loss: {:.4f}\t acc: {:.4f}'.format(loss, acc))

def test(step=None):
    xs = xp.array(np.swapaxes((x_test), 1, 3)).astype(np.float32)
    ts = xp.array(y_test).astype(np.int8)
    x = chainer.Variable(xs)
    t = chainer.Variable(ts)
    loss = model(x,t)

    n_data = len(t.data)
    total_loss = float(loss.data) * len(t.data)
    total_acc = float(model.accuracy.data) * len(t.data)
    loss = total_loss / n_data
    acc = total_acc / n_data
    print('val_loss: {:.4f}\t val_acc: {:.4f}'.format(loss, acc))

# %%
if __name__ == '__main__':
    for step in range(args.epoch):
        print('step:{}'.format(step))
        train(step)
        test(step)
# Out:
# step:0
# loss: 3.5751	 acc: 0.3906
# val_loss: 8.5442	 val_acc: 0.0000
# step:1
# loss: 8.0407	 acc: 0.1719
# val_loss: 13.1732	 val_acc: 0.3000
# step:2
# loss: 7.7798	 acc: 0.3854
# val_loss: 11.6631	 val_acc: 0.3000
# step:3
# loss: 7.0456	 acc: 0.4115
# val_loss: 8.1060	 val_acc: 0.6000
# step:4
# loss: 4.0764	 acc: 0.3906
# val_loss: 4.3288	 val_acc: 0.4000
# step:5
# loss: 5.6209	 acc: 0.3490
# val_loss: 10.7580	 val_acc: 0.1000
# step:6
# loss: 4.4397	 acc: 0.3750
# val_loss: 4.3836	 val_acc: 0.4000
# step:7
# loss: 4.8925	 acc: 0.4427
# val_loss: 8.6215	 val_acc: 0.4000
# step:8
# loss: 4.6051	 acc: 0.4740
# val_loss: 7.2969	 val_acc: 0.3000
# step:9
# loss: 4.4793	 acc: 0.5052
# val_loss: 2.8061	 val_acc: 0.3000
# step:10
# loss: 2.5130	 acc: 0.6146
# val_loss: 0.9201	 val_acc: 0.6000
# step:11
# loss: 2.0987	 acc: 0.5781
# val_loss: 3.7230	 val_acc: 0.5000
# step:12
# loss: 2.3063	 acc: 0.5469
# val_loss: 5.7828	 val_acc: 0.1000
# step:13
# loss: 1.7209	 acc: 0.5729
# val_loss: 2.2743	 val_acc: 0.6000
# step:14
# loss: 2.1668	 acc: 0.5521
# val_loss: 3.8189	 val_acc: 0.4000
# step:15
# loss: 2.3493	 acc: 0.5885
# val_loss: 3.5117	 val_acc: 0.3000
# step:16
# loss: 1.4603	 acc: 0.6094
# val_loss: 2.6805	 val_acc: 0.5000
# step:17
# loss: 1.5811	 acc: 0.6302
# val_loss: 1.0281	 val_acc: 0.6000
# step:18
# loss: 1.9639	 acc: 0.5781
# val_loss: 4.7728	 val_acc: 0.4000
# step:19
# loss: 2.2496	 acc: 0.5677
# val_loss: 1.7551	 val_acc: 0.6000
# step:20
# loss: 1.5532	 acc: 0.5833
# val_loss: 3.2365	 val_acc: 0.5000
# step:21
# loss: 0.8887	 acc: 0.7083
# val_loss: 1.3228	 val_acc: 0.7000
# step:22
# loss: 0.8654	 acc: 0.6667
# val_loss: 1.5435	 val_acc: 0.6000
# step:23
# loss: 0.8126	 acc: 0.7604
# val_loss: 1.6695	 val_acc: 0.6000
# step:24
# loss: 0.8142	 acc: 0.7344
# val_loss: 0.7621	 val_acc: 0.6000
# step:25
# loss: 0.8077	 acc: 0.7656
# val_loss: 1.1438	 val_acc: 0.6000
# step:26
# loss: 0.6483	 acc: 0.7604
# val_loss: 1.2380	 val_acc: 0.5000
# step:27
# loss: 0.6901	 acc: 0.7448
# val_loss: 2.0198	 val_acc: 0.6000
# step:28
# loss: 0.9358	 acc: 0.7188
# val_loss: 1.7156	 val_acc: 0.5000
# step:29
# loss: 0.7292	 acc: 0.7500
# val_loss: 0.6866	 val_acc: 0.7000
# step:30
# loss: 0.5582	 acc: 0.8125
# val_loss: 0.9022	 val_acc: 0.7000
# step:31
# loss: 0.5398	 acc: 0.7969
# val_loss: 1.3337	 val_acc: 0.6000
# step:32
# loss: 0.5225	 acc: 0.8125
# val_loss: 1.2681	 val_acc: 0.7000
# step:33
# loss: 0.9042	 acc: 0.7448
# val_loss: 0.9573	 val_acc: 0.7000
# step:34
# loss: 0.4998	 acc: 0.8438
# val_loss: 1.3838	 val_acc: 0.6000
# step:35
# loss: 0.5980	 acc: 0.7969
# val_loss: 0.8184	 val_acc: 0.8000
# step:36
# loss: 0.5308	 acc: 0.8125
# val_loss: 0.5312	 val_acc: 0.7000
# step:37
# loss: 0.4974	 acc: 0.8281
# val_loss: 0.9314	 val_acc: 0.7000
# step:38
# loss: 0.4990	 acc: 0.8281
# val_loss: 1.5236	 val_acc: 0.7000
# step:39
# loss: 0.5287	 acc: 0.8021
# val_loss: 0.9661	 val_acc: 0.7000
# step:40
# loss: 0.5107	 acc: 0.8229
# val_loss: 1.4469	 val_acc: 0.7000
# step:41
# loss: 0.6007	 acc: 0.8021
# val_loss: 1.4996	 val_acc: 0.5000
# step:42
# loss: 0.6859	 acc: 0.8229
# val_loss: 1.5082	 val_acc: 0.6000
# step:43
# loss: 0.6756	 acc: 0.7865
# val_loss: 1.8606	 val_acc: 0.5000
# step:44
# loss: 0.8014	 acc: 0.7865
# val_loss: 2.1566	 val_acc: 0.6000
# step:45
# loss: 0.7753	 acc: 0.7135
# val_loss: 2.0608	 val_acc: 0.7000
# step:46
# loss: 0.6269	 acc: 0.8021
# val_loss: 1.0626	 val_acc: 0.6000
# step:47
# loss: 0.6523	 acc: 0.8125
# val_loss: 1.8583	 val_acc: 0.4000
# step:48
# loss: 0.6632	 acc: 0.7865
# val_loss: 2.5851	 val_acc: 0.6000
# step:49
# loss: 0.5408	 acc: 0.8021
# val_loss: 1.3331	 val_acc: 0.7000
# step:50
# loss: 0.4957	 acc: 0.8438
# val_loss: 1.4469	 val_acc: 0.6000
# step:51
# loss: 0.5969	 acc: 0.8281
# val_loss: 2.2909	 val_acc: 0.5000
# step:52
# loss: 0.5550	 acc: 0.8333
# val_loss: 1.5802	 val_acc: 0.6000
# step:53
# loss: 0.5308	 acc: 0.8125
# val_loss: 1.2029	 val_acc: 0.7000
# step:54
# loss: 0.4608	 acc: 0.8542
# val_loss: 1.6023	 val_acc: 0.6000
# step:55
# loss: 0.4718	 acc: 0.8542
# val_loss: 1.5395	 val_acc: 0.7000
# step:56
# loss: 0.5320	 acc: 0.8490
# val_loss: 1.5094	 val_acc: 0.6000
# step:57
# loss: 0.5242	 acc: 0.8125
# val_loss: 1.5401	 val_acc: 0.6000
# step:58
# loss: 0.3457	 acc: 0.8698
# val_loss: 1.5577	 val_acc: 0.6000
# step:59
# loss: 0.4179	 acc: 0.8229
# val_loss: 1.4355	 val_acc: 0.7000
# step:60
# loss: 0.3350	 acc: 0.8750
# val_loss: 1.1305	 val_acc: 0.7000
# step:61
# loss: 0.2713	 acc: 0.9167
# val_loss: 1.4724	 val_acc: 0.8000
# step:62
# loss: 0.2755	 acc: 0.9010
# val_loss: 2.0169	 val_acc: 0.7000
# step:63
# loss: 0.1922	 acc: 0.9479
# val_loss: 1.6332	 val_acc: 0.7000
# step:64
# loss: 0.2711	 acc: 0.9010
# val_loss: 1.6064	 val_acc: 0.8000
# step:65
# loss: 0.4650	 acc: 0.8438
# val_loss: 1.4999	 val_acc: 0.7000
# step:66
# loss: 0.2764	 acc: 0.9323
# val_loss: 1.3258	 val_acc: 0.7000
# step:67
# loss: 0.2728	 acc: 0.8906
# val_loss: 1.7583	 val_acc: 0.7000
# step:68
# loss: 0.2623	 acc: 0.8958
# val_loss: 2.0428	 val_acc: 0.7000
# step:69
# loss: 0.3563	 acc: 0.8958
# val_loss: 1.2818	 val_acc: 0.7000
# step:70
# loss: 0.4043	 acc: 0.8438
# val_loss: 2.0697	 val_acc: 0.6000
# step:71
# loss: 0.3661	 acc: 0.8958
# val_loss: 1.1136	 val_acc: 0.5000
# step:72
# loss: 0.2486	 acc: 0.9062
# val_loss: 1.1489	 val_acc: 0.8000
# step:73
# loss: 0.3194	 acc: 0.8646
# val_loss: 1.9625	 val_acc: 0.7000
# step:74
# loss: 0.2903	 acc: 0.9115
# val_loss: 2.2368	 val_acc: 0.6000
# step:75
# loss: 0.2676	 acc: 0.9167
# val_loss: 1.8290	 val_acc: 0.5000
# step:76
# loss: 0.2833	 acc: 0.9115
# val_loss: 2.2691	 val_acc: 0.6000
# step:77
# loss: 0.3268	 acc: 0.8698
# val_loss: 1.8209	 val_acc: 0.8000
# step:78
# loss: 0.3146	 acc: 0.8646
# val_loss: 1.4109	 val_acc: 0.7000
# step:79
# loss: 0.3517	 acc: 0.8854
# val_loss: 1.0431	 val_acc: 0.7000
# step:80
# loss: 0.2443	 acc: 0.9115
# val_loss: 1.5170	 val_acc: 0.5000
# step:81
# loss: 0.2182	 acc: 0.9375
# val_loss: 1.7882	 val_acc: 0.7000
# step:82
# loss: 0.2480	 acc: 0.9115
# val_loss: 1.9593	 val_acc: 0.8000
# step:83
# loss: 0.1479	 acc: 0.9531
# val_loss: 2.0057	 val_acc: 0.8000
# step:84
# loss: 0.2498	 acc: 0.9323
# val_loss: 1.9979	 val_acc: 0.8000
# step:85
# loss: 0.1550	 acc: 0.9323
# val_loss: 1.9116	 val_acc: 0.8000
# step:86
# loss: 0.1477	 acc: 0.9583
# val_loss: 1.8827	 val_acc: 0.7000
# step:87
# loss: 0.1332	 acc: 0.9635
# val_loss: 1.8414	 val_acc: 0.7000
# step:88
# loss: 0.0877	 acc: 0.9688
# val_loss: 1.8085	 val_acc: 0.6000
# step:89
# loss: 0.1292	 acc: 0.9427
# val_loss: 1.8093	 val_acc: 0.6000
# step:90
# loss: 0.3090	 acc: 0.9115
# val_loss: 2.2563	 val_acc: 0.6000
# step:91
# loss: 0.2901	 acc: 0.9115
# val_loss: 1.4056	 val_acc: 0.7000
# step:92
# loss: 0.2677	 acc: 0.9219
# val_loss: 1.5491	 val_acc: 0.7000
# step:93
# loss: 0.1745	 acc: 0.9479
# val_loss: 1.7790	 val_acc: 0.8000
# step:94
# loss: 0.2565	 acc: 0.9010
# val_loss: 1.6649	 val_acc: 0.6000
# step:95
# loss: 0.2570	 acc: 0.8958
# val_loss: 1.6604	 val_acc: 0.6000
# step:96
# loss: 0.1001	 acc: 0.9635
# val_loss: 1.4345	 val_acc: 0.7000
# step:97
# loss: 0.1268	 acc: 0.9583
# val_loss: 1.4665	 val_acc: 0.7000
# step:98
# loss: 0.1847	 acc: 0.9375
# val_loss: 1.8248	 val_acc: 0.7000
# step:99
# loss: 0.1702	 acc: 0.9375
# val_loss: 2.2333	 val_acc: 0.7000
