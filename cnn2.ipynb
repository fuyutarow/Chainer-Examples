# %%
from __future__ import print_function
import os

import pandas as pd
from PIL import Image
import numpy as np

import chainer
from chainer.dataset import convert
import chainer.links as L
import chainer.functions as F
from chainer import serializers

from chainer.datasets import get_cifar10
from chainer.datasets import get_cifar100

import utils
# Out:
# Using TensorFlow backend.
# /home/fytroo/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# ### ハイパーパラメータ

# %%
from easydict import EasyDict
args = EasyDict({
    'bs': 64, 
    'epoch' : 100,
    'lr' : 0.05,
    'gpu': 0,
    'out': 'result',
    'resume': '',
    'n_in': 32, 
})
try:
    __file__.endswith('py')
    import argparse
    parser = argparse.ArgumentParser(description='Chainer example: MNIST')
    parser.add_argument('--batchsize', '-b', dest='bs', type=int, default=args.bs,
                        help='Number of images in each mini-batch')
    parser.add_argument('--epoch', '-e', type=int, default=args.epoch,
                        help='Number of sweeps over the dataset to train')
    parser.add_argument('--learningrate', '-l', dest='lr', type=float, default=args.lr,
                        help='Number of sweeps over the dataset to train')
    parser.add_argument('--frequency', '-f', type=int, default=-1,
                        help='Frequency of taking a snapshot')
    parser.add_argument('--gpu', '-g', type=int, default=args.gpu,
                        help='GPU ID (negative value indicates CPU)')
    parser.add_argument('--out', '-o', default=args.out,
                        help='Directory to output the result')
    parser.add_argument('--resume', '-r', default=args.resume,
                        help='Resume the training from snapshot')
    parser.add_argument('--unit', '-u', dest='n_in', type=int, default=args.n_in,
                        help='Number of units')
    parser.add_argument('--noplot', dest='plot', action='store_false',
                        help='Disable PlotReport extension')
    args = parser.parse_args()
except:
    print('no argsparse')
    pass
# Out:
# no argsparse

# %% [markdown]
# ### データセット読み込み

# %%
dataset_dir = 'flower_images'
df  = pd.DataFrame.from_csv(os.path.join(dataset_dir,'flower_labels.csv'))

df['name'] = df.index
df['path'] = dataset_dir + '/' + df['name']

n_label = df.label.drop_duplicates().count()
n_label
df
# Out:
# /home/fytroo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#           label      name                    path
# file
# 0001.png      0  0001.png  flower_images/0001.png
# 0002.png      0  0002.png  flower_images/0002.png
# 0003.png      2  0003.png  flower_images/0003.png
# 0004.png      0  0004.png  flower_images/0004.png
# 0005.png      0  0005.png  flower_images/0005.png
# 0006.png      1  0006.png  flower_images/0006.png
# 0007.png      6  0007.png  flower_images/0007.png
# 0008.png      0  0008.png  flower_images/0008.png
# 0009.png      0  0009.png  flower_images/0009.png
# 0010.png      0  0010.png  flower_images/0010.png
# 0011.png      0  0011.png  flower_images/0011.png
# 0012.png      0  0012.png  flower_images/0012.png
# 0013.png      0  0013.png  flower_images/0013.png
# 0014.png      7  0014.png  flower_images/0014.png
# 0015.png      7  0015.png  flower_images/0015.png
# 0016.png      1  0016.png  flower_images/0016.png
# 0017.png      0  0017.png  flower_images/0017.png
# 0018.png      0  0018.png  flower_images/0018.png
# 0019.png      6  0019.png  flower_images/0019.png
# 0020.png      0  0020.png  flower_images/0020.png
# 0021.png      2  0021.png  flower_images/0021.png
# 0022.png      4  0022.png  flower_images/0022.png
# 0023.png      7  0023.png  flower_images/0023.png
# 0024.png      4  0024.png  flower_images/0024.png
# 0025.png      5  0025.png  flower_images/0025.png
# 0026.png      6  0026.png  flower_images/0026.png
# 0027.png      2  0027.png  flower_images/0027.png
# 0028.png      5  0028.png  flower_images/0028.png
# 0029.png      6  0029.png  flower_images/0029.png
# 0030.png      6  0030.png  flower_images/0030.png
# ...         ...       ...                     ...
# 0181.png      0  0181.png  flower_images/0181.png
# 0182.png      5  0182.png  flower_images/0182.png
# 0183.png      8  0183.png  flower_images/0183.png
# 0184.png      6  0184.png  flower_images/0184.png
# 0185.png      3  0185.png  flower_images/0185.png
# 0186.png      9  0186.png  flower_images/0186.png
# 0187.png      6  0187.png  flower_images/0187.png
# 0188.png      1  0188.png  flower_images/0188.png
# 0189.png      3  0189.png  flower_images/0189.png
# 0190.png      7  0190.png  flower_images/0190.png
# 0191.png      4  0191.png  flower_images/0191.png
# 0192.png      7  0192.png  flower_images/0192.png
# 0193.png      1  0193.png  flower_images/0193.png
# 0194.png      9  0194.png  flower_images/0194.png
# 0195.png      8  0195.png  flower_images/0195.png
# 0196.png      3  0196.png  flower_images/0196.png
# 0197.png      6  0197.png  flower_images/0197.png
# 0198.png      5  0198.png  flower_images/0198.png
# 0199.png      6  0199.png  flower_images/0199.png
# 0200.png      4  0200.png  flower_images/0200.png
# 0201.png      1  0201.png  flower_images/0201.png
# 0202.png      3  0202.png  flower_images/0202.png
# 0203.png      8  0203.png  flower_images/0203.png
# 0204.png      5  0204.png  flower_images/0204.png
# 0205.png      4  0205.png  flower_images/0205.png
# 0206.png      6  0206.png  flower_images/0206.png
# 0207.png      0  0207.png  flower_images/0207.png
# 0208.png      4  0208.png  flower_images/0208.png
# 0209.png      6  0209.png  flower_images/0209.png
# 0210.png      1  0210.png  flower_images/0210.png
#
# [210 rows x 3 columns]

# %%
def load_fromdf(dataframe, resize=(96,96)):
    if type(resize) is int:
        resize = (resize, resize)
    
    df = dataframe
    x_data = []
    y_data = []
    for idx, row in df.iterrows():
        y = row['label']
        f = row['path']

        img = Image.open(f).resize(resize, Image.LANCZOS)
        img = img.convert('RGB')
        x = np.array(img)
        x_data.append(x)
        y_data.append(y)
    x_data = np.array(x_data)
    y_data = np.array(y_data)

    return x_data, y_data

# %%
df_train, df_test = utils.train_test_split_df(df, test_size=0.1)
x_train, y_train = load_fromdf(df_train, resize=args.n_in)
x_test, y_test = load_fromdf(df_test, resize=args.n_in)

x_train.shape
# Out:
# (200, 32, 32, 3)

# %% [markdown]
# ### モデルを定義

# %%
class Fire(chainer.Chain):
    def __init__(self, n_in=None, n_out=32, depth=1):
        super(Fire, self).__init__()
        with self.init_scope():
            self.conv1 = L.Convolution2D(n_in, 32, 3)
            self.conv2 = L.Convolution2D(None, n_out, 3)
            self.bn = L.BatchNormalization(32)
            self.bn2 = L.BatchNormalization(32)
    
    def __call__(self, x):
        x = self.bn(x)
        x = self.conv1(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = self.conv2(x)
        return x

# %%
class LeNet(chainer.Chain):
    def __init__(self, n_in=32, n_out=10):
        super(LeNet, self).__init__()
        with self.init_scope():
            self.conv1 = L.Convolution2D(None, 32, 3)
            self.fire1 = Fire(None, 32, depth=2)
            self.fire2 = Fire(None, 32, depth=2)
            self.fc = L.Linear(None, n_out)
    
    def __call__(self, x):
        x = self.conv1(x)
        x = self.fire1(x)
        x = F.max_pooling_2d(x, ksize=2, stride=2)
        x = self.fire2(x)
        x = F.average_pooling_2d(x, ksize=2, stride=2)
        x = self.fc(x)
        return x

# %%
model = L.Classifier(LeNet(args.n_in, n_label),
                    lossfun=F.softmax_cross_entropy,
                    accfun=F.accuracy)
xp = np
if args.gpu >= 0:
    import cupy as cp
    xp = cp
    chainer.cuda.get_device_from_id(args.gpu).use()
    model.to_gpu()  # Copy the model to the GPU
optimizer = chainer.optimizers.MomentumSGD(args.lr)
optimizer.setup(model)

# %% [markdown]
# ### data augmentation

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape

import Augmentor
p = Augmentor.Pipeline()
p.flip_left_right(probability=0.5)
p.flip_top_bottom(probability=0.5)
g = p.keras_generator_from_array(x_train, y_train, batch_size=args.bs)
g = ((
    xp.array(np.swapaxes((x/255.), 1, 3)).astype(np.float32),
    xp.array(y.astype(np.int8))
    ) for (x,y) in g)

# %% [markdown]
# chainer.trainingを使わず，訓練ループをかく
# chainer.trainingでは，自前のデータのイテレータを使うことができないため．
# Augmentorを使いたい

# %% [markdown]
# ### 訓練と検証

# %%
def train(step=None):
    total_loss = 0
    total_acc = 0
    n_data = 0
    n_train = len(y_train)
    for _ in range(n_train//args.bs):
        xs, ts = next(g) 
        x = chainer.Variable(xs)
        t = chainer.Variable(ts)
        optimizer.update(model, x, t)
        with chainer.using_config('train', True):
            loss = model(x,t)
        n_data += len(t.data)
        total_loss += float(loss.data) * len(t.data)
        total_acc += float(model.accuracy.data) * len(t.data)

    loss = total_loss / n_data
    acc = total_acc / n_data
    print('loss: {:.4f}\t acc: {:.4f}'.format(loss, acc))

def test(step=None):
    xs = xp.array(np.swapaxes((x_test), 1, 3)).astype(np.float32)
    ts = xp.array(y_test).astype(np.int8)
    x = chainer.Variable(xs)
    t = chainer.Variable(ts)
    loss = model(x,t)

    n_data = len(t.data)
    total_loss = float(loss.data) * len(t.data)
    total_acc = float(model.accuracy.data) * len(t.data)
    loss = total_loss / n_data
    acc = total_acc / n_data
    print('val_loss: {:.4f}\t val_acc: {:.4f}'.format(loss, acc))

# %%
if __name__ == '__main__':
    for step in range(args.epoch):
        print('step:{}'.format(step))
        train(step)
        test(step)
# Out:
# step:0
# loss: 1.6222	 acc: 0.5104
# val_loss: 1.8783	 val_acc: 0.5000
# step:1
# loss: 1.1456	 acc: 0.5885
# val_loss: 1.5848	 val_acc: 0.5000
# step:2
# loss: 0.9136	 acc: 0.7292
# val_loss: 1.1478	 val_acc: 0.7000
# step:3
# loss: 1.1240	 acc: 0.6146
# val_loss: 1.4752	 val_acc: 0.5000
# step:4
# loss: 1.7785	 acc: 0.5208
# val_loss: 3.9189	 val_acc: 0.3000
# step:5
# loss: 1.6708	 acc: 0.4948
# val_loss: 2.3503	 val_acc: 0.5000
# step:6
# loss: 1.5232	 acc: 0.4792
# val_loss: 2.3875	 val_acc: 0.2000
# step:7
# loss: 1.3800	 acc: 0.5521
# val_loss: 1.5821	 val_acc: 0.4000
# step:8
# loss: 1.0040	 acc: 0.6562
# val_loss: 1.8422	 val_acc: 0.5000
# step:9
# loss: 1.0504	 acc: 0.6667
# val_loss: 1.1445	 val_acc: 0.7000
# step:10
# loss: 1.0370	 acc: 0.7031
# val_loss: 0.9926	 val_acc: 0.6000
# step:11
# loss: 1.1020	 acc: 0.6719
# val_loss: 1.7667	 val_acc: 0.5000
# step:12
# loss: 0.9824	 acc: 0.6458
# val_loss: 1.6604	 val_acc: 0.5000
# step:13
# loss: 0.7444	 acc: 0.7292
# val_loss: 0.9098	 val_acc: 0.8000
# step:14
# loss: 0.7997	 acc: 0.7448
# val_loss: 0.6785	 val_acc: 0.7000
# step:15
# loss: 0.7238	 acc: 0.7604
# val_loss: 0.6861	 val_acc: 0.8000
# step:16
# loss: 0.4581	 acc: 0.8854
# val_loss: 0.6221	 val_acc: 0.8000
# step:17
# loss: 0.6631	 acc: 0.7812
# val_loss: 0.9292	 val_acc: 0.6000
# step:18
# loss: 0.6474	 acc: 0.7917
# val_loss: 1.2099	 val_acc: 0.6000
# step:19
# loss: 0.5551	 acc: 0.8021
# val_loss: 1.1443	 val_acc: 0.6000
# step:20
# loss: 0.5568	 acc: 0.8073
# val_loss: 0.9837	 val_acc: 0.6000
# step:21
# loss: 0.6206	 acc: 0.7917
# val_loss: 0.9282	 val_acc: 0.7000
# step:22
# loss: 0.5226	 acc: 0.8125
# val_loss: 1.4001	 val_acc: 0.6000
# step:23
# loss: 0.5833	 acc: 0.7708
# val_loss: 1.3395	 val_acc: 0.5000
# step:24
# loss: 0.4981	 acc: 0.8333
# val_loss: 1.3238	 val_acc: 0.5000
# step:25
# loss: 0.3863	 acc: 0.8646
# val_loss: 0.9819	 val_acc: 0.6000
# step:26
# loss: 0.4854	 acc: 0.8333
# val_loss: 1.3985	 val_acc: 0.7000
# step:27
# loss: 0.5119	 acc: 0.8021
# val_loss: 1.4835	 val_acc: 0.6000
# step:28
# loss: 0.4490	 acc: 0.8594
# val_loss: 1.4808	 val_acc: 0.5000
# step:29
# loss: 0.3906	 acc: 0.8490
# val_loss: 1.0493	 val_acc: 0.6000
# step:30
# loss: 0.3908	 acc: 0.8646
# val_loss: 1.3344	 val_acc: 0.7000
# step:31
# loss: 0.4732	 acc: 0.8125
# val_loss: 1.5386	 val_acc: 0.6000
# step:32
# loss: 0.3407	 acc: 0.8750
# val_loss: 0.9516	 val_acc: 0.7000
# step:33
# loss: 0.4257	 acc: 0.8542
# val_loss: 0.9130	 val_acc: 0.6000
# step:34
# loss: 0.3250	 acc: 0.8906
# val_loss: 1.6562	 val_acc: 0.4000
# step:35
# loss: 0.3644	 acc: 0.8906
# val_loss: 0.9069	 val_acc: 0.6000
# step:36
# loss: 0.3667	 acc: 0.8646
# val_loss: 1.0160	 val_acc: 0.7000
# step:37
# loss: 0.3072	 acc: 0.8958
# val_loss: 0.7897	 val_acc: 0.8000
# step:38
# loss: 0.2053	 acc: 0.9167
# val_loss: 1.2826	 val_acc: 0.7000
# step:39
# loss: 0.2572	 acc: 0.8958
# val_loss: 1.7825	 val_acc: 0.6000
# step:40
# loss: 0.3565	 acc: 0.8802
# val_loss: 1.8067	 val_acc: 0.4000
# step:41
# loss: 0.1716	 acc: 0.9479
# val_loss: 0.9160	 val_acc: 0.5000
# step:42
# loss: 0.1663	 acc: 0.9531
# val_loss: 0.8851	 val_acc: 0.6000
# step:43
# loss: 0.2680	 acc: 0.9010
# val_loss: 0.8136	 val_acc: 0.5000
# step:44
# loss: 0.1559	 acc: 0.9583
# val_loss: 0.8812	 val_acc: 0.6000
# step:45
# loss: 0.1488	 acc: 0.9583
# val_loss: 1.0174	 val_acc: 0.6000
# step:46
# loss: 0.2311	 acc: 0.9479
# val_loss: 1.3319	 val_acc: 0.7000
# step:47
# loss: 0.1692	 acc: 0.9375
# val_loss: 1.1162	 val_acc: 0.6000
# step:48
# loss: 0.1668	 acc: 0.9635
# val_loss: 0.6734	 val_acc: 0.7000
# step:49
# loss: 0.1839	 acc: 0.9427
# val_loss: 0.8786	 val_acc: 0.7000
# step:50
# loss: 0.1111	 acc: 0.9531
# val_loss: 1.2827	 val_acc: 0.6000
# step:51
# loss: 0.1119	 acc: 0.9688
# val_loss: 1.2396	 val_acc: 0.7000
# step:52
# loss: 0.1530	 acc: 0.9688
# val_loss: 1.1125	 val_acc: 0.7000
# step:53
# loss: 0.1710	 acc: 0.9479
# val_loss: 0.9071	 val_acc: 0.6000
# step:54
# loss: 0.2219	 acc: 0.9427
# val_loss: 0.9476	 val_acc: 0.6000
# step:55
# loss: 0.1116	 acc: 0.9635
# val_loss: 1.5201	 val_acc: 0.6000
# step:56
# loss: 0.1791	 acc: 0.9583
# val_loss: 1.2154	 val_acc: 0.6000
# step:57
# loss: 0.1177	 acc: 0.9635
# val_loss: 1.1286	 val_acc: 0.6000
# step:58
# loss: 0.1131	 acc: 0.9688
# val_loss: 1.1917	 val_acc: 0.6000
# step:59
# loss: 0.1205	 acc: 0.9635
# val_loss: 1.1637	 val_acc: 0.7000
# step:60
# loss: 0.2191	 acc: 0.9167
# val_loss: 1.4435	 val_acc: 0.5000
# step:61
# loss: 0.1559	 acc: 0.9427
# val_loss: 1.5766	 val_acc: 0.5000
# step:62
# loss: 0.1843	 acc: 0.9375
# val_loss: 1.5358	 val_acc: 0.4000
# step:63
# loss: 0.1080	 acc: 0.9635
# val_loss: 1.4249	 val_acc: 0.5000
# step:64
# loss: 0.1272	 acc: 0.9479
# val_loss: 0.6491	 val_acc: 0.7000
# step:65
# loss: 0.1116	 acc: 0.9583
# val_loss: 0.9215	 val_acc: 0.6000
# step:66
# loss: 0.0959	 acc: 0.9792
# val_loss: 1.3161	 val_acc: 0.6000
# step:67
# loss: 0.0836	 acc: 0.9844
# val_loss: 1.4731	 val_acc: 0.6000
# step:68
# loss: 0.0800	 acc: 0.9844
# val_loss: 1.9289	 val_acc: 0.5000
# step:69
# loss: 0.0710	 acc: 0.9740
# val_loss: 1.7352	 val_acc: 0.6000
# step:70
# loss: 0.0739	 acc: 0.9792
# val_loss: 0.9840	 val_acc: 0.7000
# step:71
# loss: 0.0946	 acc: 0.9740
# val_loss: 1.1033	 val_acc: 0.6000
# step:72
# loss: 0.0769	 acc: 0.9740
# val_loss: 1.2973	 val_acc: 0.6000
# step:73
# loss: 0.0719	 acc: 0.9896
# val_loss: 1.0428	 val_acc: 0.6000
# step:74
# loss: 0.0717	 acc: 0.9792
# val_loss: 0.7822	 val_acc: 0.8000
# step:75
# loss: 0.0947	 acc: 0.9688
# val_loss: 1.2172	 val_acc: 0.7000
# step:76
# loss: 0.0568	 acc: 0.9844
# val_loss: 1.0115	 val_acc: 0.6000
# step:77
# loss: 0.0801	 acc: 0.9740
# val_loss: 1.4945	 val_acc: 0.4000
# step:78
# loss: 0.0844	 acc: 0.9688
# val_loss: 1.5860	 val_acc: 0.6000
# step:79
# loss: 0.1222	 acc: 0.9583
# val_loss: 1.7788	 val_acc: 0.4000
# step:80
# loss: 0.0640	 acc: 0.9792
# val_loss: 1.8730	 val_acc: 0.4000
# step:81
# loss: 0.0491	 acc: 0.9896
# val_loss: 1.8320	 val_acc: 0.6000
# step:82
# loss: 0.0625	 acc: 0.9740
# val_loss: 1.4887	 val_acc: 0.7000
# step:83
# loss: 0.0628	 acc: 0.9740
# val_loss: 1.5964	 val_acc: 0.6000
# step:84
# loss: 0.0914	 acc: 0.9688
# val_loss: 1.7721	 val_acc: 0.6000
# step:85
# loss: 0.0352	 acc: 0.9948
# val_loss: 2.0100	 val_acc: 0.6000
# step:86
# loss: 0.1027	 acc: 0.9688
# val_loss: 1.9097	 val_acc: 0.6000
# step:87
# loss: 0.0758	 acc: 0.9844
# val_loss: 1.6217	 val_acc: 0.6000
# step:88
# loss: 0.0637	 acc: 0.9844
# val_loss: 1.5774	 val_acc: 0.6000
# step:89
# loss: 0.0262	 acc: 1.0000
# val_loss: 1.2708	 val_acc: 0.6000
# step:90
# loss: 0.0646	 acc: 0.9792
# val_loss: 1.0343	 val_acc: 0.7000
# step:91
# loss: 0.0252	 acc: 1.0000
# val_loss: 1.0199	 val_acc: 0.6000
# step:92
# loss: 0.0567	 acc: 0.9792
# val_loss: 2.1016	 val_acc: 0.5000
# step:93
# loss: 0.0289	 acc: 0.9948
# val_loss: 1.2352	 val_acc: 0.6000
# step:94
# loss: 0.0546	 acc: 0.9896
# val_loss: 1.4359	 val_acc: 0.5000
# step:95
# loss: 0.0366	 acc: 0.9896
# val_loss: 1.2299	 val_acc: 0.6000
# step:96
# loss: 0.0194	 acc: 1.0000
# val_loss: 1.1763	 val_acc: 0.6000
# step:97
# loss: 0.0378	 acc: 1.0000
# val_loss: 1.0694	 val_acc: 0.8000
# step:98
# loss: 0.0188	 acc: 1.0000
# val_loss: 0.8902	 val_acc: 0.8000
# step:99
# loss: 0.0358	 acc: 0.9896
# val_loss: 1.0038	 val_acc: 0.6000
