# %%
from __future__ import print_function
import os

import pandas as pd
from PIL import Image
import numpy as np

import chainer
from chainer.dataset import convert
import chainer.links as L
import chainer.functions as F
from chainer import serializers

from chainer.datasets import get_cifar10
from chainer.datasets import get_cifar100

import easydict
import utils
# Out:
# Using TensorFlow backend.
# /home/fytroo/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
from easydict import EasyDict
args = EasyDict({
    'bs': 64, 
    'epoch' : 100,
    'lr' : 0.05,
    'gpu': 0,
    'out': 'result',
    'resume': '',
    'n_in': 32, 
})
try:
    __file__.endswith('py')
    import argparse
    parser = argparse.ArgumentParser(description='Chainer example: MNIST')
    parser.add_argument('--batchsize', '-b', dest='bs', type=int, default=args.bs,
                        help='Number of images in each mini-batch')
    parser.add_argument('--epoch', '-e', type=int, default=args.epoch,
                        help='Number of sweeps over the dataset to train')
    parser.add_argument('--learningrate', '-l', dest='lr', type=float, default=args.lr,
                        help='Number of sweeps over the dataset to train')
    parser.add_argument('--frequency', '-f', type=int, default=-1,
                        help='Frequency of taking a snapshot')
    parser.add_argument('--gpu', '-g', type=int, default=args.gpu,
                        help='GPU ID (negative value indicates CPU)')
    parser.add_argument('--out', '-o', default=args.out,
                        help='Directory to output the result')
    parser.add_argument('--resume', '-r', default=args.resume,
                        help='Resume the training from snapshot')
    parser.add_argument('--unit', '-u', dest='n_in', type=int, default=args.n_in,
                        help='Number of units')
    parser.add_argument('--noplot', dest='plot', action='store_false',
                        help='Disable PlotReport extension')
    args = parser.parse_args()
except:
    print('no argsparse')
    pass
# Out:
# no argsparse

# %%
dataset_dir = 'flower_images'
df  = pd.DataFrame.from_csv(os.path.join(dataset_dir,'flower_labels.csv'))

df['name'] = df.index
df['path'] = dataset_dir + '/' + df['name']

n_label = df.label.drop_duplicates().count()
n_label
df
# Out:
# /home/fytroo/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#           label      name                    path
# file
# 0001.png      0  0001.png  flower_images/0001.png
# 0002.png      0  0002.png  flower_images/0002.png
# 0003.png      2  0003.png  flower_images/0003.png
# 0004.png      0  0004.png  flower_images/0004.png
# 0005.png      0  0005.png  flower_images/0005.png
# 0006.png      1  0006.png  flower_images/0006.png
# 0007.png      6  0007.png  flower_images/0007.png
# 0008.png      0  0008.png  flower_images/0008.png
# 0009.png      0  0009.png  flower_images/0009.png
# 0010.png      0  0010.png  flower_images/0010.png
# 0011.png      0  0011.png  flower_images/0011.png
# 0012.png      0  0012.png  flower_images/0012.png
# 0013.png      0  0013.png  flower_images/0013.png
# 0014.png      7  0014.png  flower_images/0014.png
# 0015.png      7  0015.png  flower_images/0015.png
# 0016.png      1  0016.png  flower_images/0016.png
# 0017.png      0  0017.png  flower_images/0017.png
# 0018.png      0  0018.png  flower_images/0018.png
# 0019.png      6  0019.png  flower_images/0019.png
# 0020.png      0  0020.png  flower_images/0020.png
# 0021.png      2  0021.png  flower_images/0021.png
# 0022.png      4  0022.png  flower_images/0022.png
# 0023.png      7  0023.png  flower_images/0023.png
# 0024.png      4  0024.png  flower_images/0024.png
# 0025.png      5  0025.png  flower_images/0025.png
# 0026.png      6  0026.png  flower_images/0026.png
# 0027.png      2  0027.png  flower_images/0027.png
# 0028.png      5  0028.png  flower_images/0028.png
# 0029.png      6  0029.png  flower_images/0029.png
# 0030.png      6  0030.png  flower_images/0030.png
# ...         ...       ...                     ...
# 0181.png      0  0181.png  flower_images/0181.png
# 0182.png      5  0182.png  flower_images/0182.png
# 0183.png      8  0183.png  flower_images/0183.png
# 0184.png      6  0184.png  flower_images/0184.png
# 0185.png      3  0185.png  flower_images/0185.png
# 0186.png      9  0186.png  flower_images/0186.png
# 0187.png      6  0187.png  flower_images/0187.png
# 0188.png      1  0188.png  flower_images/0188.png
# 0189.png      3  0189.png  flower_images/0189.png
# 0190.png      7  0190.png  flower_images/0190.png
# 0191.png      4  0191.png  flower_images/0191.png
# 0192.png      7  0192.png  flower_images/0192.png
# 0193.png      1  0193.png  flower_images/0193.png
# 0194.png      9  0194.png  flower_images/0194.png
# 0195.png      8  0195.png  flower_images/0195.png
# 0196.png      3  0196.png  flower_images/0196.png
# 0197.png      6  0197.png  flower_images/0197.png
# 0198.png      5  0198.png  flower_images/0198.png
# 0199.png      6  0199.png  flower_images/0199.png
# 0200.png      4  0200.png  flower_images/0200.png
# 0201.png      1  0201.png  flower_images/0201.png
# 0202.png      3  0202.png  flower_images/0202.png
# 0203.png      8  0203.png  flower_images/0203.png
# 0204.png      5  0204.png  flower_images/0204.png
# 0205.png      4  0205.png  flower_images/0205.png
# 0206.png      6  0206.png  flower_images/0206.png
# 0207.png      0  0207.png  flower_images/0207.png
# 0208.png      4  0208.png  flower_images/0208.png
# 0209.png      6  0209.png  flower_images/0209.png
# 0210.png      1  0210.png  flower_images/0210.png
#
# [210 rows x 3 columns]

# %%
def load_fromdf(dataframe, resize=(96,96)):
    if type(resize) is int:
        resize = (resize, resize)
    
    df = dataframe
    x_data = []
    y_data = []
    for idx, row in df.iterrows():
        y = row['label']
        f = row['path']

        img = Image.open(f).resize(resize, Image.LANCZOS)
        img = img.convert('RGB')
        x = np.array(img)
        x_data.append(x)
        y_data.append(y)
    x_data = np.array(x_data)
    y_data = np.array(y_data)

    return x_data, y_data

# %%
df_train, df_test = utils.train_test_split_df(df, test_size=0.1)
x_train, y_train = load_fromdf(df_train, resize=args.n_in)
x_test, y_test = load_fromdf(df_test, resize=args.n_in)

x_train.shape
# Out:
# (200, 32, 32, 3)

# %%
class Fire(chainer.Chain):
    def __init__(self, n_in=None, n_out=32):
        super(Fire, self).__init__()
        with self.init_scope():
            self.conv1 = L.Convolution2D(n_in, 32, 3)
            self.conv2 = L.Convolution2D(None, n_out, 3)
            self.bn = L.BatchNormalization(32)
            self.bn2 = L.BatchNormalization(32)
    
    def __call__(self, x):
        x = self.conv1(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = self.conv2(x)
        return x

# %%
class Fire(chainer.Chain):
    def __init__(self, n_in=None, n_out=32):
        super(Fire, self).__init__()
        with self.init_scope():
            self.conv1 = L.Convolution2D(n_in, 32, 3)
            self.conv2 = L.Convolution2D(None, n_out, 3)
            self.bn = L.BatchNormalization(32)
            self.bn2 = L.BatchNormalization(32)
            self.bn3 = L.BatchNormalization(32)
    
    def __call__(self, x):
        x = self.bn(x)
        x = self.conv1(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = self.bn3(x)
        return x

# %%
class LeNet(chainer.Chain):
    def __init__(self, n_in=32, n_out=10):
        super(LeNet, self).__init__()
        with self.init_scope():
            self.conv1 = L.Convolution2D(None, 32, 3)
            self.fire1 = Fire(None, 32)
            self.fire2 = Fire(None, 32)
            self.fc = L.Linear(None, n_out)
    
    def __call__(self, x):
        x = self.conv1(x)
        #x = F.average_pooling_2d(x, ksize=2, stride=2)
        x = self.fire1(x)
        x = self.fire2(x)
        x = F.average_pooling_2d(x, ksize=2, stride=2)
        x = self.fc(x)
        return x

# %%
model = L.Classifier(LeNet(args.n_in, n_label),
                    lossfun=F.softmax_cross_entropy,
                    accfun=F.accuracy)
xp = np
if args.gpu >= 0:
    import cupy as cp
    xp = cp
    chainer.cuda.get_device_from_id(args.gpu).use()
    model.to_gpu()  # Copy the model to the GPU
optimizer = chainer.optimizers.MomentumSGD(args.lr)
optimizer.setup(model)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape

import Augmentor
p = Augmentor.Pipeline()
p.flip_left_right(probability=0.5)
p.flip_top_bottom(probability=0.5)
g = p.keras_generator_from_array(x_train, y_train, batch_size=args.bs)
g = ((
    xp.array(np.swapaxes((x/255.), 1, 3)).astype(np.float32),
    xp.array(y.astype(np.int8))
    ) for (x,y) in g)

# %% [markdown]
# chainer.trainingを使わず，訓練ループをかく
# chainer.trainingでは，自前のデータのイテレータを使うことができないため．
# Augmentorを使いたい

# %%
def train(step=None):
    total_loss = 0
    total_acc = 0
    n_data = 0
    n_train = len(y_train)
    for _ in range(n_train//args.bs):
        xs, ts = next(g) 
        x = chainer.Variable(xs)
        t = chainer.Variable(ts)
        optimizer.update(model, x, t)
        loss = model(x,t)
        n_data += len(t.data)
        total_loss += float(loss.data) * len(t.data)
        total_acc += float(model.accuracy.data) * len(t.data)

    if step is None:
        print('step:{}\t loss: {:.4f}\t acc: {:.4f}'.format(step, total_loss/n_data, total_acc/n_data))
    else:
        print('loss: {:.4f}\t acc: {:.4f}'.format(total_loss/n_data, total_acc/n_data))

# %%
def test():
    xs = xp.array(np.swapaxes((x_test), 1, 3)).astype(np.float32)
    ts = xp.array(y_test).astype(np.int8)
    x = chainer.Variable(xs)
    t = chainer.Variable(ts)
    loss = model(x,t)

    n_data = len(t.data)
    total_loss = float(loss.data) * len(t.data)
    total_acc = float(model.accuracy.data) * len(t.data)

    print('val_loss: {:.4f}\t val_acc: {:.4f}'.format(total_loss/n_data, total_acc/n_data))

# %%
if __name__ == '__main__':
    for i in range(args.epoch):
        print('step:{}'.format(i))
        train()
        test()
# Out:
# step:0
# step:None	 loss: 1.3283	 acc: 0.6875
# val_loss: 4.2058	 val_acc: 0.3000
# step:1
# step:None	 loss: 3.1967	 acc: 0.4115
# val_loss: 4.3544	 val_acc: 0.3000
# step:2
# step:None	 loss: 5.7570	 acc: 0.3750
# val_loss: 8.5053	 val_acc: 0.1000
# step:3
# step:None	 loss: 5.1287	 acc: 0.4323
# val_loss: 5.3702	 val_acc: 0.6000
# step:4
# step:None	 loss: 2.7387	 acc: 0.6146
# val_loss: 2.2670	 val_acc: 0.6000
# step:5
# step:None	 loss: 3.1742	 acc: 0.4896
# val_loss: 3.2789	 val_acc: 0.3000
# step:6
# step:None	 loss: 3.2305	 acc: 0.3438
# val_loss: 2.3065	 val_acc: 0.5000
# step:7
# step:None	 loss: 2.5398	 acc: 0.4583
# val_loss: 2.5574	 val_acc: 0.3000
# step:8
# step:None	 loss: 2.1910	 acc: 0.4010
# val_loss: 1.9377	 val_acc: 0.5000
# step:9
# step:None	 loss: 2.1119	 acc: 0.4688
# val_loss: 3.3458	 val_acc: 0.5000
# step:10
# step:None	 loss: 1.6022	 acc: 0.5781
# val_loss: 2.6457	 val_acc: 0.4000
# step:11
# step:None	 loss: 1.6988	 acc: 0.5885
# val_loss: 1.9158	 val_acc: 0.6000
# step:12
# step:None	 loss: 1.5696	 acc: 0.6042
# val_loss: 2.2182	 val_acc: 0.4000
# step:13
# step:None	 loss: 1.6497	 acc: 0.5729
# val_loss: 2.6525	 val_acc: 0.6000
# step:14
# step:None	 loss: 1.5549	 acc: 0.6250
# val_loss: 1.5741	 val_acc: 0.8000
# step:15
# step:None	 loss: 1.8349	 acc: 0.5573
# val_loss: 2.2071	 val_acc: 0.4000
# step:16
# step:None	 loss: 1.6934	 acc: 0.6146
# val_loss: 1.7697	 val_acc: 0.5000
# step:17
# step:None	 loss: 1.4158	 acc: 0.5990
# val_loss: 1.6541	 val_acc: 0.4000
# step:18
# step:None	 loss: 1.2934	 acc: 0.6771
# val_loss: 2.6578	 val_acc: 0.3000
# step:19
# step:None	 loss: 1.0203	 acc: 0.6250
# val_loss: 0.6839	 val_acc: 0.6000
# step:20
# step:None	 loss: 1.4078	 acc: 0.5833
# val_loss: 0.7114	 val_acc: 0.7000
# step:21
# step:None	 loss: 1.2496	 acc: 0.6406
# val_loss: 1.4956	 val_acc: 0.4000
# step:22
# step:None	 loss: 0.9282	 acc: 0.7917
# val_loss: 1.4385	 val_acc: 0.6000
# step:23
# step:None	 loss: 0.8789	 acc: 0.7552
# val_loss: 0.9115	 val_acc: 0.8000
# step:24
# step:None	 loss: 0.9229	 acc: 0.6719
# val_loss: 0.7687	 val_acc: 0.8000
# step:25
# step:None	 loss: 0.6663	 acc: 0.7604
# val_loss: 1.2601	 val_acc: 0.7000
# step:26
# step:None	 loss: 0.6929	 acc: 0.7292
# val_loss: 1.2601	 val_acc: 0.6000
# step:27
# step:None	 loss: 0.6808	 acc: 0.7656
# val_loss: 0.8976	 val_acc: 0.7000
# step:28
# step:None	 loss: 0.7965	 acc: 0.7500
# val_loss: 1.0425	 val_acc: 0.6000
# step:29
# step:None	 loss: 0.7033	 acc: 0.7760
# val_loss: 2.1909	 val_acc: 0.4000
# step:30
# step:None	 loss: 0.5983	 acc: 0.7865
# val_loss: 0.9106	 val_acc: 0.7000
# step:31
# step:None	 loss: 0.7305	 acc: 0.7865
# val_loss: 0.7518	 val_acc: 0.8000
# step:32
# step:None	 loss: 0.6715	 acc: 0.7552
# val_loss: 0.8083	 val_acc: 0.7000
# step:33
# step:None	 loss: 0.6154	 acc: 0.8229
# val_loss: 1.5377	 val_acc: 0.5000
# step:34
# step:None	 loss: 0.5517	 acc: 0.7969
# val_loss: 1.6739	 val_acc: 0.5000
# step:35
# step:None	 loss: 0.5304	 acc: 0.8125
# val_loss: 1.1659	 val_acc: 0.6000
# step:36
# step:None	 loss: 0.6313	 acc: 0.8073
# val_loss: 0.6756	 val_acc: 0.7000
# step:37
# step:None	 loss: 0.5822	 acc: 0.8125
# val_loss: 0.8739	 val_acc: 0.7000
# step:38
# step:None	 loss: 0.5102	 acc: 0.8281
# val_loss: 1.1440	 val_acc: 0.6000
# step:39
# step:None	 loss: 0.4432	 acc: 0.8229
# val_loss: 1.0885	 val_acc: 0.6000
# step:40
# step:None	 loss: 0.3779	 acc: 0.8438
# val_loss: 0.9121	 val_acc: 0.6000
# step:41
# step:None	 loss: 0.3789	 acc: 0.8594
# val_loss: 0.7729	 val_acc: 0.9000
# step:42
# step:None	 loss: 0.2731	 acc: 0.8802
# val_loss: 0.7814	 val_acc: 0.5000
# step:43
# step:None	 loss: 0.2506	 acc: 0.9167
# val_loss: 0.9298	 val_acc: 0.6000
# step:44
# step:None	 loss: 0.1726	 acc: 0.9375
# val_loss: 0.7947	 val_acc: 0.6000
# step:45
# step:None	 loss: 0.1632	 acc: 0.9323
# val_loss: 0.8154	 val_acc: 0.6000
# step:46
# step:None	 loss: 0.2853	 acc: 0.8854
# val_loss: 0.9780	 val_acc: 0.6000
# step:47
# step:None	 loss: 0.3369	 acc: 0.8802
# val_loss: 1.5943	 val_acc: 0.6000
# step:48
# step:None	 loss: 0.2622	 acc: 0.8854
# val_loss: 1.3635	 val_acc: 0.6000
# step:49
# step:None	 loss: 0.2497	 acc: 0.9323
# val_loss: 1.1125	 val_acc: 0.7000
# step:50
# step:None	 loss: 0.1943	 acc: 0.9375
# val_loss: 1.5853	 val_acc: 0.5000
# step:51
# step:None	 loss: 0.2875	 acc: 0.8958
# val_loss: 1.0901	 val_acc: 0.6000
# step:52
# step:None	 loss: 0.2719	 acc: 0.9010
# val_loss: 1.3295	 val_acc: 0.7000
# step:53
# step:None	 loss: 0.3859	 acc: 0.8802
# val_loss: 1.2715	 val_acc: 0.6000
# step:54
# step:None	 loss: 0.3233	 acc: 0.8750
# val_loss: 1.7103	 val_acc: 0.5000
# step:55
# step:None	 loss: 0.2222	 acc: 0.9115
# val_loss: 1.6787	 val_acc: 0.6000
# step:56
# step:None	 loss: 0.5454	 acc: 0.8385
# val_loss: 1.6389	 val_acc: 0.7000
# step:57
# step:None	 loss: 0.2364	 acc: 0.9271
# val_loss: 1.8803	 val_acc: 0.6000
# step:58
# step:None	 loss: 0.2355	 acc: 0.9010
# val_loss: 1.9719	 val_acc: 0.4000
# step:59
# step:None	 loss: 0.2628	 acc: 0.9115
# val_loss: 2.0927	 val_acc: 0.4000
# step:60
# step:None	 loss: 0.2401	 acc: 0.9427
# val_loss: 1.7786	 val_acc: 0.5000
# step:61
# step:None	 loss: 0.2096	 acc: 0.9427
# val_loss: 1.2434	 val_acc: 0.7000
# step:62
# step:None	 loss: 0.2205	 acc: 0.9375
# val_loss: 0.9665	 val_acc: 0.8000
# step:63
# step:None	 loss: 0.2180	 acc: 0.9375
# val_loss: 1.1199	 val_acc: 0.7000
# step:64
# step:None	 loss: 0.2068	 acc: 0.9427
# val_loss: 1.3777	 val_acc: 0.7000
# step:65
# step:None	 loss: 0.3116	 acc: 0.9062
# val_loss: 1.1300	 val_acc: 0.6000
# step:66
# step:None	 loss: 0.1205	 acc: 0.9635
# val_loss: 0.8964	 val_acc: 0.8000
# step:67
# step:None	 loss: 0.1867	 acc: 0.9323
# val_loss: 1.3567	 val_acc: 0.7000
# step:68
# step:None	 loss: 0.1735	 acc: 0.9219
# val_loss: 1.1240	 val_acc: 0.8000
# step:69
# step:None	 loss: 0.1863	 acc: 0.9323
# val_loss: 0.7131	 val_acc: 0.7000
# step:70
# step:None	 loss: 0.1856	 acc: 0.9219
# val_loss: 0.3149	 val_acc: 0.9000
# step:71
# step:None	 loss: 0.0693	 acc: 0.9844
# val_loss: 0.5563	 val_acc: 0.8000
# step:72
# step:None	 loss: 0.0984	 acc: 0.9531
# val_loss: 0.8374	 val_acc: 0.8000
# step:73
# step:None	 loss: 0.1364	 acc: 0.9479
# val_loss: 1.5128	 val_acc: 0.7000
# step:74
# step:None	 loss: 0.1881	 acc: 0.9323
# val_loss: 1.3211	 val_acc: 0.8000
# step:75
# step:None	 loss: 0.2123	 acc: 0.9479
# val_loss: 0.9392	 val_acc: 0.7000
# step:76
# step:None	 loss: 0.1347	 acc: 0.9583
# val_loss: 1.0683	 val_acc: 0.7000
# step:77
# step:None	 loss: 0.0566	 acc: 0.9896
# val_loss: 1.3971	 val_acc: 0.6000
# step:78
# step:None	 loss: 0.0897	 acc: 0.9792
# val_loss: 1.5824	 val_acc: 0.7000
# step:79
# step:None	 loss: 0.0690	 acc: 0.9792
# val_loss: 1.6312	 val_acc: 0.7000
# step:80
# step:None	 loss: 0.0849	 acc: 0.9740
# val_loss: 1.9404	 val_acc: 0.4000
# step:81
# step:None	 loss: 0.0699	 acc: 0.9792
# val_loss: 1.9494	 val_acc: 0.6000
# step:82
# step:None	 loss: 0.0645	 acc: 0.9740
# val_loss: 1.7323	 val_acc: 0.6000
# step:83
# step:None	 loss: 0.0255	 acc: 1.0000
# val_loss: 1.4131	 val_acc: 0.6000
# step:84
# step:None	 loss: 0.0981	 acc: 0.9740
# val_loss: 1.2151	 val_acc: 0.6000
# step:85
# step:None	 loss: 0.0916	 acc: 0.9792
# val_loss: 1.2135	 val_acc: 0.7000
# step:86
# step:None	 loss: 0.0906	 acc: 0.9583
# val_loss: 1.6417	 val_acc: 0.5000
# step:87
# step:None	 loss: 0.1016	 acc: 0.9479
# val_loss: 0.9889	 val_acc: 0.9000
# step:88
# step:None	 loss: 0.1115	 acc: 0.9635
# val_loss: 1.1294	 val_acc: 0.7000
# step:89
# step:None	 loss: 0.0976	 acc: 0.9635
# val_loss: 1.4497	 val_acc: 0.7000
# step:90
# step:None	 loss: 0.1469	 acc: 0.9479
# val_loss: 1.7446	 val_acc: 0.4000
# step:91
# step:None	 loss: 0.1459	 acc: 0.9479
# val_loss: 1.5701	 val_acc: 0.6000
# step:92
# step:None	 loss: 0.1001	 acc: 0.9740
# val_loss: 1.3557	 val_acc: 0.5000
# step:93
# step:None	 loss: 0.0813	 acc: 0.9844
# val_loss: 0.9414	 val_acc: 0.5000
# step:94
# step:None	 loss: 0.0893	 acc: 0.9740
# val_loss: 0.9950	 val_acc: 0.6000
# step:95
# step:None	 loss: 0.0804	 acc: 0.9635
# val_loss: 1.1874	 val_acc: 0.7000
# step:96
# step:None	 loss: 0.1502	 acc: 0.9427
# val_loss: 0.6275	 val_acc: 0.6000
# step:97
# step:None	 loss: 0.0658	 acc: 0.9740
# val_loss: 1.0406	 val_acc: 0.6000
# step:98
# step:None	 loss: 0.0628	 acc: 0.9844
# val_loss: 1.6947	 val_acc: 0.5000
# step:99
# step:None	 loss: 0.1001	 acc: 0.9688
# val_loss: 0.9343	 val_acc: 0.6000

# %%
x, y = x_train, y_train
xs, ys = (
    xp.array(np.swapaxes((x/255.), 1, 3)).astype('f'),
    xp.array(y.astype('i')))
res = model(chainer.Variable(xs), chainer.Variable(ys))

# %%
res
# Out:
# variable(0.06057498976588249)
